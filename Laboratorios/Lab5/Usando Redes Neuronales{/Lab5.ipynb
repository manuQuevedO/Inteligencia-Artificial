# %%
# used for manipulating directory paths
import os

# Scientific and vector computation for python
import numpy as np

# Plotting library
from matplotlib import pyplot

# Optimization module in scipy
from scipy import optimize

# will be used to load MATLAB mat datafile format
from scipy.io import loadmat


import pandas as pd

#esta tabulate nos sirve para hacer tablas
from tabulate import tabulate

# Librerias para graficación (trazado de gráficos)
from matplotlib import pyplot
# tells matplotlib to embed plots within the notebook

#Para separa el 20% y 80%
from sklearn.model_selection import train_test_split
# %matplotlib inline

# %% [markdown]
# # Red nueronal

# %%
dataset = pd.read_csv('BirdSpecies_dataset.csv', delimiter=',')


# dataset = pd.read_csv('OnlineNewsPopularity.csv', delimiter=',')
#para usarlo a travez de google colab
dataset = dataset.sample(n=20000, random_state=42)

dataset
# Out:
#        BodyLength  Wingspan  Weight  PlumageColorHead  PlumageColorBack  \
# 6868        5.501     0.398   6.846             0.805             0.325
# 24016       6.444     8.711   1.309             0.890             8.843
# 9668        0.273     5.533   4.428             5.289             5.419
# 13640       8.912     1.691   9.683             2.847             2.258
# 14018       3.513     8.207   6.038             3.123             0.663
# ...           ...       ...     ...               ...               ...
# 3791        8.214     8.988   0.101             2.497             5.954
# 23445       7.663     6.968   8.822             7.402             9.460
# 14154       4.681     7.425   5.612             8.761             8.511
# 2786        3.211     6.911   3.306             4.846             7.787
# 9259        1.864     6.024   9.642             0.929             9.840
#
#        PlumageColorBelly  PlumageColorWings  PlumageColorTail  BeakLength  \
# 6868               7.072              0.497             6.905       9.287
# 24016              7.327              3.221             8.431       6.331
# 9668               0.798              8.739             5.877       0.304
# 13640              2.951              6.249             9.674       4.296
# 14018              2.423              4.136             1.694       0.988
# ...                  ...                ...               ...         ...
# 3791               7.443              7.401             3.670       9.307
# 23445              2.592              5.008             7.041       9.135
# 14154              5.891              5.465             8.920       8.096
# 2786               4.685              9.147             3.835       7.194
# 9259               8.300              6.191             0.574       2.066
#
#        BeakWidth  ...  SeedDispersalRole  InterspecificInteraction  \
# 6868       1.472  ...              5.650                     2.046
# 24016      2.556  ...              0.635                     8.539
# 9668       1.938  ...              2.613                     7.502
# 13640      1.164  ...              0.250                     6.526
# 14018      5.227  ...              9.547                     8.516
# ...          ...  ...                ...                       ...
# 3791       2.224  ...              8.079                     2.908
# 23445      5.077  ...              9.649                     7.073
# 14154      3.858  ...              7.815                     2.034
# 2786       2.015  ...              8.205                     2.636
# 9259       1.835  ...              3.082                     9.056
#
#        IntraspecificInteraction  LearningAbility  ToolUse  ParentalCareLevel  \
# 6868                      9.993            1.066    0.567              7.668
# 24016                     8.770            9.193    2.581              5.422
# 9668                      6.780            6.684    2.246              9.646
# 13640                     4.387            7.123    2.318              1.063
# 14018                     7.609            0.631    7.271              4.115
# ...                         ...              ...      ...                ...
# 3791                      3.623            6.811    7.126              5.741
# 23445                     2.362            1.960    4.795              0.132
# 14154                     7.907            1.465    4.242              2.601
# 2786                      1.068            1.729    9.482              4.961
# 9259                      2.841            1.363    7.602              7.336
#
#        BathingBehavior  GroomingBehavior  FlightSpeed  SpeciesClass
# 6868             1.344             7.939        8.780             1
# 24016            7.256             7.390        3.678             5
# 9668             5.405             4.260        2.110             3
# 13640            3.434             6.701        4.200             3
# 14018            8.989             1.458        7.585             4
# ...                ...               ...          ...           ...
# 3791             1.905             0.220        5.953             1
# 23445            7.835             3.740        0.055             4
# 14154            2.348             1.814        4.335             2
# 2786             0.762             7.486        8.716             0
# 9259             6.821             3.003        8.583             3
#
# [20000 rows x 61 columns]

# %% [markdown]
# ## Tratamiento de datos
#
# vamos a eliminar las columnas de nuestro dataset que no necesitamos, en este caso la direccion de url:

# %%
#dropeamos la columna de url
dataset = dataset.drop(['ColorVision','NocturnalVision'], axis=1)

dataset
# Out:
#        BodyLength  Wingspan  Weight  PlumageColorHead  PlumageColorBack  \
# 6868        5.501     0.398   6.846             0.805             0.325
# 24016       6.444     8.711   1.309             0.890             8.843
# 9668        0.273     5.533   4.428             5.289             5.419
# 13640       8.912     1.691   9.683             2.847             2.258
# 14018       3.513     8.207   6.038             3.123             0.663
# ...           ...       ...     ...               ...               ...
# 3791        8.214     8.988   0.101             2.497             5.954
# 23445       7.663     6.968   8.822             7.402             9.460
# 14154       4.681     7.425   5.612             8.761             8.511
# 2786        3.211     6.911   3.306             4.846             7.787
# 9259        1.864     6.024   9.642             0.929             9.840
#
#        PlumageColorBelly  PlumageColorWings  PlumageColorTail  BeakLength  \
# 6868               7.072              0.497             6.905       9.287
# 24016              7.327              3.221             8.431       6.331
# 9668               0.798              8.739             5.877       0.304
# 13640              2.951              6.249             9.674       4.296
# 14018              2.423              4.136             1.694       0.988
# ...                  ...                ...               ...         ...
# 3791               7.443              7.401             3.670       9.307
# 23445              2.592              5.008             7.041       9.135
# 14154              5.891              5.465             8.920       8.096
# 2786               4.685              9.147             3.835       7.194
# 9259               8.300              6.191             0.574       2.066
#
#        BeakWidth  ...  SeedDispersalRole  InterspecificInteraction  \
# 6868       1.472  ...              5.650                     2.046
# 24016      2.556  ...              0.635                     8.539
# 9668       1.938  ...              2.613                     7.502
# 13640      1.164  ...              0.250                     6.526
# 14018      5.227  ...              9.547                     8.516
# ...          ...  ...                ...                       ...
# 3791       2.224  ...              8.079                     2.908
# 23445      5.077  ...              9.649                     7.073
# 14154      3.858  ...              7.815                     2.034
# 2786       2.015  ...              8.205                     2.636
# 9259       1.835  ...              3.082                     9.056
#
#        IntraspecificInteraction  LearningAbility  ToolUse  ParentalCareLevel  \
# 6868                      9.993            1.066    0.567              7.668
# 24016                     8.770            9.193    2.581              5.422
# 9668                      6.780            6.684    2.246              9.646
# 13640                     4.387            7.123    2.318              1.063
# 14018                     7.609            0.631    7.271              4.115
# ...                         ...              ...      ...                ...
# 3791                      3.623            6.811    7.126              5.741
# 23445                     2.362            1.960    4.795              0.132
# 14154                     7.907            1.465    4.242              2.601
# 2786                      1.068            1.729    9.482              4.961
# 9259                      2.841            1.363    7.602              7.336
#
#        BathingBehavior  GroomingBehavior  FlightSpeed  SpeciesClass
# 6868             1.344             7.939        8.780             1
# 24016            7.256             7.390        3.678             5
# 9668             5.405             4.260        2.110             3
# 13640            3.434             6.701        4.200             3
# 14018            8.989             1.458        7.585             4
# ...                ...               ...          ...           ...
# 3791             1.905             0.220        5.953             1
# 23445            7.835             3.740        0.055             4
# 14154            2.348             1.814        4.335             2
# 2786             0.762             7.486        8.716             0
# 9259             6.821             3.003        8.583             3
#
# [20000 rows x 59 columns]

# %% [markdown]
# ## Analisis del dataset
#
# para tener una mejor vista del los tipos de datos del dataset, hacemos un `info()`:

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 20000 entries, 6868 to 9259
# Data columns (total 59 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   BodyLength                20000 non-null  float64
#  1   Wingspan                  20000 non-null  float64
#  2   Weight                    20000 non-null  float64
#  3   PlumageColorHead          20000 non-null  float64
#  4   PlumageColorBack          20000 non-null  float64
#  5   PlumageColorBelly         20000 non-null  float64
#  6   PlumageColorWings         20000 non-null  float64
#  7   PlumageColorTail          20000 non-null  float64
#  8   BeakLength                20000 non-null  float64
#  9   BeakWidth                 20000 non-null  float64
#  10  BeakShape                 20000 non-null  float64
#  11  BeakColor                 20000 non-null  float64
#  12  LegLength                 20000 non-null  float64
#  13  LegColor                  20000 non-null  float64
#  14  FootType                  20000 non-null  float64
#  15  EyeColor                  20000 non-null  float64
#  16  DietType                  20000 non-null  float64
#  17  FeedingBehavior           20000 non-null  float64
#  18  PreferredHabitat          20000 non-null  float64
#  19  GeographicalRange         20000 non-null  float64
#  20  MigratoryBehavior         20000 non-null  float64
#  21  BreedingSeason            20000 non-null  float64
#  22  NestType                  20000 non-null  float64
#  23  ClutchSize                20000 non-null  float64
#  24  EggColor                  20000 non-null  float64
#  25  IncubationPeriod          20000 non-null  float64
#  26  FledglingPeriod           20000 non-null  float64
#  27  SocialBehavior            20000 non-null  float64
#  28  FlightPattern             20000 non-null  float64
#  29  VocalizationType          20000 non-null  float64
#  30  SoundFrequency            20000 non-null  float64
#  31  TypicalActivityPeriod     20000 non-null  float64
#  32  Predators                 20000 non-null  float64
#  33  Lifespan                  20000 non-null  float64
#  34  SexualDimorphism          20000 non-null  float64
#  35  MoltFrequency             20000 non-null  float64
#  36  TarsusLength              20000 non-null  float64
#  37  WingShape                 20000 non-null  float64
#  38  TailShape                 20000 non-null  float64
#  39  ConservationStatus        20000 non-null  float64
#  40  TerritorialBehavior       20000 non-null  float64
#  41  MigrationDistance         20000 non-null  float64
#  42  ForagingHeight            20000 non-null  float64
#  43  WaterDependency           20000 non-null  float64
#  44  TemperaturePreference     20000 non-null  float64
#  45  HearingAcuity             20000 non-null  float64
#  46  OlfactoryAcuity           20000 non-null  float64
#  47  TouchSensitivity          20000 non-null  float64
#  48  PollinationRole           20000 non-null  float64
#  49  SeedDispersalRole         20000 non-null  float64
#  50  InterspecificInteraction  20000 non-null  float64
#  51  IntraspecificInteraction  20000 non-null  float64
#  52  LearningAbility           20000 non-null  float64
#  53  ToolUse                   20000 non-null  float64
#  54  ParentalCareLevel         20000 non-null  float64
#  55  BathingBehavior           20000 non-null  float64
#  56  GroomingBehavior          20000 non-null  float64
#  57  FlightSpeed               20000 non-null  float64
#  58  SpeciesClass              20000 non-null  int64
# dtypes: float64(58), int64(1)
# memory usage: 9.2 MB

# %% [markdown]
# ## Separacion del 80% de los datos para entrenamiento y 20% para pruebas
#
# Haremos uso de la libreria `sklearn` haciendo uso de su funcion `train_test_split()`, donde recibe como parametros:

# %%
#separamos el 20% para test y el 80% para entrenamiento deld dataset
train_dataset, test_dataset = train_test_split(dataset, test_size=0.2, random_state=42)

# Seleccionamos las columnas para X y la columna 'shares' para y
X_test = test_dataset.drop(['SpeciesClass'], axis=1).values
y_test = test_dataset['SpeciesClass'].values
m_test = len(y_test)

# Seleccionamos las columnas para X y la columna 'shares' para y
X_train = train_dataset.drop(['SpeciesClass'], axis=1).values
y_train = train_dataset['SpeciesClass'].values
m_train = len(y_train)
# Ahora, X y y deberían contener datos numéricos del 80% del dataset



# imprimir todos las X de datos solo 10
print(X_train)
print(y_train)
# Out:
# [[8.172 2.631 4.667 ... 9.824 6.542 3.675]
#  [4.655 5.623 8.604 ... 3.616 0.751 6.725]
#  [3.717 1.057 6.497 ... 3.597 6.919 2.699]
#  ...
#  [9.492 4.574 8.266 ... 6.454 0.556 4.924]
#  [2.556 5.462 2.754 ... 9.017 9.052 0.395]
#  [6.63  7.11  7.519 ... 9.443 3.919 6.309]]
# [1 5 5 ... 2 4 0]

# %%
print(f"el 80% de datos es:{X_train.shape[0]} y el 20% es: {X_test.shape[0]}")
print( "la totalidad de datos es: ", dataset.shape[0])
# Out:
# el 80% de datos es:16000 y el 20% es: 4000
# la totalidad de datos es:  20000

# %%
### Usamos el shape para tener una imagen mas clara de las entradas

#Con esta funcion podemos obtener la cantidad de caracteristicas que estamos usando y la cantidad de ejemplos que contiene nuestra matriz.

print("la cantidad de columnas es: ", X_train.shape[1])
print("la cantidad de ejemplos es: ", X_train.shape[0])
# Out:
# la cantidad de columnas es:  58
# la cantidad de ejemplos es:  16000

# %%
# En este apartado definiremos la cantidad de capas que tendra el modelo:

# - **Capa de entrada:** Es la cantidad de caracteristicas con las que cuenta el dataset.

# - **Capa oculta:** esto se define haciendo pruebas.

# - **Capa de salida:**como este modelo es de regresion lineal, se debe usar solo una capa de salida.

# Configurando parametros necesario
input_layer_size  = X_train.shape[1]  
hidden_layer_size = 9   
num_labels = 6         

print("capa de entrada es: ",input_layer_size)
print("capa de oculta es: ",hidden_layer_size)
print("capa de salida es: ",num_labels)
# Out:
# capa de entrada es:  58
# capa de oculta es:  9
# capa de salida es:  6

# %%
## Inicializacion de Thetas

# Inicializamos los valores de theta1 y theta2 con valores aleatorios para evitar conflictos:
# Los valores aleatorios aseguran que cada neurona pueda aprender patrones distintos, lo cual es crucial para el buen desempeño de la red.
pesos = {}
pesos['Theta1'] = np.random.rand(hidden_layer_size , input_layer_size + 1)
pesos['Theta2'] = np.random.rand(num_labels, hidden_layer_size + 1)

# %% [markdown]
# ### Guardamos los valores de theta en nuevas variables
#
# `.ravel()` Convertira las matrices Theta1 y Tetha2 en vectores unidimencionales.

# %%
# Al inicializar los pesos con valores aleatorios pequeños, se garantiza que las neuronas en una capa oculta comiencen a 
# aprender diferentes funciones. Esto aumenta la capacidad de representación de la red neuronal y permite que aprenda patrones 
# complejos en los datos de entrada. Además, la aleatorización ayuda a evitar que el algoritmo de aprendizaje se atasque en mínimos locales 
# subóptimos durante el entrenamiento.

Theta1, Theta2 = pesos['Theta1'], pesos['Theta2']


print("El tamaño de Theta1 es de: ",Theta1.ravel().shape)
print("El tamaño de Theta2 es de: ",Theta2.ravel().shape)
# Out:
# El tamaño de Theta1 es de:  (531,)
# El tamaño de Theta2 es de:  (60,)

# %%
## Concadenamos Theta1 y Theta2 para formar un solo array
nn_params = np.concatenate([Theta1.ravel(), Theta2.ravel()])
print(nn_params.shape)
# Out:
# (591,)

# %%
###               Funcion de activacion

# Esta función simplemente pasa la entrada directamente a la salida sin aplicar ninguna transformación no lineal.

# def linear_activation(z):
#     return z

# def linear_gradient(z):
#     return np.ones_like(z)


import numpy as np

def softmax(z):
    exp_z = np.exp(z - np.max(z, axis=-1, keepdims=True)) # Evita problemas de estabilidad numérica
    return exp_z / np.sum(exp_z, axis=-1, keepdims=True)

def softmax_gradient(z):
    s = softmax(z)
    return s * (1 - s)  # Derivada de la función Softmax

# %% [markdown]
# ## Funcion de costo

# %%
print(nn_params.shape)
# Out:
# (591,)

# %%
# permite saber si el modelo está haciendo un buen trabajo al comparar las predicciones del modelo con los valores reales que deberían ser.

# la regularización se utiliza en dos lugares principales para ayudar a prevenir el sobreajuste modificando tanto el cálculo del costo como la 
# actualización de los gradientes de los pesos. 

def nnCostFunction(nn_params,
                   input_layer_size,
                   hidden_layer_size,
                   num_labels,
                   X, y, lambda_=0.0):

    # Reshape nn_params para obtener Theta1 y Theta2
    Theta1 = np.reshape(nn_params[:hidden_layer_size * (input_layer_size + 1)],
                        (hidden_layer_size, (input_layer_size + 1)))
    Theta2 = np.reshape(nn_params[(hidden_layer_size * (input_layer_size + 1)):],
                        (num_labels, (hidden_layer_size + 1)))

    m = y.size  # Número de ejemplos de entrenamiento

    J = 0
    Theta1_grad = np.zeros(Theta1.shape)
    Theta2_grad = np.zeros(Theta2.shape)

    # Propagación hacia adelante
    a1 = np.concatenate([np.ones((m, 1)), X], axis=1)
    z2 = a1.dot(Theta1.T)
    a2 = softmax(z2)
    a2 = np.concatenate([np.ones((a2.shape[0], 1)), a2], axis=1)
    z3 = a2.dot(Theta2.T)
    a3 = softmax(z3)

    # Asegurar que y tenga la forma adecuada
    y = y.reshape(-1, 1)

    #                Función de costo

    #El término de regularización se añade al costo total para penalizar los valores grandes de los pesos. 
    # Esto ayuda a mantener los pesos pequeños, lo que generalmente conduce a un modelo menos complejo y más generalizable.
    reg_term = (lambda_ / (2 * m)) * (np.sum(np.square(Theta1[:, 1:])) + np.sum(np.square(Theta2[:, 1:])))
    J = (1 / (2 * m)) * np.sum(np.square(a3 - y))
    J += reg_term

    # Retropropagación
    delta_3 = a3 - y
    delta_2 = delta_3.dot(Theta2)[:, 1:] * softmax_gradient(z2)

    Delta1 = delta_2.T.dot(a1)
    Delta2 = delta_3.T.dot(a2)

    #                    Regularización de gradientes
    # Esto se hace para asegurar que la penalización aplicada a los pesos a través de la función de costo se refleje también en la forma en que
    # los gradientes ajustan estos pesos durante el entrenamiento.
    Theta1_grad = (1 / m) * Delta1
    Theta1_grad[:, 1:] += (lambda_ / m) * Theta1[:, 1:]
    Theta2_grad = (1 / m) * Delta2
    Theta2_grad[:, 1:] += (lambda_ / m) * Theta2[:, 1:]

    # Desenrollar gradientes
    grad = np.concatenate([Theta1_grad.ravel(), Theta2_grad.ravel()])

    return J, grad

# %%
## Normalizacion de los datos


#Al visualizar los datos se puede observar que las caracteristicas tienen diferentes magnitudes, por lo cual se debe transformar cada valor 
# en una escala de valores similares.

def  featureNormalize(X):
    X_norm = X.copy()

    #creamos un array de ceros con una longitud igual al número de columnas en el array X. La variable mu y sigma se inicializa como este array de ceros.
    mu = np.zeros(X.shape[1])
    sigma = np.zeros(X.shape[1])

    #Creamos el promedio de cada columna de X
    mu = np.mean(X, axis = 0)
    sigma = np.std(X, axis = 0)

    sigma[sigma == 0] = 1

    #normalizamos los datos con la siguiente formula
    X_norm = (X - mu) / sigma

    return X_norm, mu, sigma

# %%
X_norm, mu, sigma = featureNormalize(X_train)

# %%
print("Longitud de nn_params:", len(nn_params))
print("Expected size for Theta2:", (hidden_layer_size + 1) * num_labels)
# Out:
# Longitud de nn_params: 591
# Expected size for Theta2: 60

# %% [markdown]
# ## Calculo del costo

# %%
lambda_ = 10000
J, _ = nnCostFunction(nn_params, input_layer_size, hidden_layer_size, num_labels, X_norm, y_train, lambda_)
print('Costo en parametros (cargado de ex4weights): %.6f ' % J)
#print('El costo debe esta cercano a
# Out:
# Costo en parametros (cargado de ex4weights): 87.706911

# %% [markdown]
# ## Inicializar pesos aleatorios
#
#
#
# La matriz de pesos inicializada aleatoriamente se devuelve como salida de la función.

# %%
#La función randInitializeWeights que has definido es un método común para inicializar los pesos de una red neuronal 
# de manera aleatoria. Esta inicialización es crucial para asegurar que la red neuronal comience el aprendizaje con una ruptura de simetría, 
# permitiendo que las neuronas aprendan diferentes funciones.

def randInitializeWeights(L_in, L_out, epsilon_init=0.12):

    W = np.zeros((L_out, 1 + L_in))
    W = np.random.rand(L_out, 1 + L_in) * 2 * epsilon_init - epsilon_init

    return W

# %%
print('Inicialización de parámetros de redes neuronales...')

initial_Theta1 = randInitializeWeights(input_layer_size, hidden_layer_size)
initial_Theta2 = randInitializeWeights(hidden_layer_size, num_labels)

# Desenrrollr parametros
initial_nn_params = np.concatenate([initial_Theta1.ravel(), initial_Theta2.ravel()], axis=0)
# Out:
# Inicialización de parámetros de redes neuronales...

# %%
## Calculo de Thetas

# Después de haber completado la tarea, cambie el maxiter a uno más grande
# Usando un numero maximo de iteraciones
options= {'maxiter': 10000}

# Tratamos con diferentes valores de lambda_
lambda_ = 1

# define una función anónima (lambda) llamada costFunction.
costFunction = lambda p: nnCostFunction(p, input_layer_size,
                                        hidden_layer_size,
                                        num_labels, X_norm, y_train, lambda_)

# Ahora, costFunction es una función que toma solo un argumento.
# (los parámetros de la red neuronal)
res = optimize.minimize(costFunction,
                        initial_nn_params,
                        jac=True,
                        method='TNC',
                        options=options)

# obtenemos la solución de la optimización
nn_params = res.x

# Obtenemos Theta1 y Theta2 de nn_params
Theta1 = np.reshape(nn_params[:hidden_layer_size * (input_layer_size + 1)],
                    (hidden_layer_size, (input_layer_size + 1)))

Theta2 = np.reshape(nn_params[(hidden_layer_size * (input_layer_size + 1)):],
                    (num_labels, (hidden_layer_size + 1)))
# Out:
# C:\Users\Manuel\AppData\Local\Temp\ipykernel_24068\3311480215.py:17: OptimizeWarning: Unknown solver options: maxiter
#   res = optimize.minimize(costFunction,

# %%
for i in range(len(Theta1)):
    print("Thetha",i,"es: ", Theta1[i])
    print("")
# Out:
# Thetha 0 es:  [ 0.00689772  0.09217307 -0.09894664  0.09456197 -0.08253116 -0.08711445
#   0.11437279 -0.04450613 -0.00505212 -0.1175531   0.00890481 -0.11531673
#   0.10688457  0.07020571 -0.11736101  0.02390581  0.10705661  0.10275758
#   0.10090868 -0.06067839  0.09995444  0.07882862  0.07559065 -0.01060503
#   0.04419121 -0.05407899 -0.04315506  0.09466233 -0.01565307  0.02087181
#   0.0742021   0.07451553  0.07375455 -0.10016464 -0.00884323 -0.02252134
#  -0.05477311 -0.0530116   0.10681123  0.09436004  0.10992021 -0.00305563
#  -0.00417708  0.07217276 -0.06573479  0.00945167  0.11387754  0.05479473
#  -0.02392123  0.0857498  -0.07615058  0.08041883 -0.10939324  0.10291206
#   0.0241693  -0.04186985  0.04769836  0.04822406  0.10786122]
#
# Thetha 1 es:  [-0.08242108  0.03538628 -0.00107819  0.06568612  0.03998907 -0.05489562
#   0.00638213 -0.06062198 -0.11565901 -0.08661602  0.05845594 -0.00278417
#   0.08119536 -0.02928327  0.03919074 -0.03795501  0.02612297 -0.00748384
#  -0.11071147  0.04570384 -0.01377614 -0.01783007  0.1028155   0.00102276
#   0.08699947 -0.00076932 -0.11334463 -0.10833024  0.0293514   0.05290898
#   0.09033783 -0.01619186 -0.08161601 -0.07425662 -0.0053241  -0.07885253
#   0.08156005  0.01887726 -0.1142183   0.01029229 -0.06624307  0.02711869
#   0.00937818  0.09188667  0.08057692 -0.06695954  0.04606969 -0.03704442
#  -0.09687921 -0.11879015 -0.07171636  0.08758921 -0.11232753  0.06932909
#   0.05258098  0.01757279 -0.00314975 -0.01869647 -0.03928417]
#
# Thetha 2 es:  [ 0.09801734  0.00681138  0.08729173 -0.08838256 -0.02009613  0.08473725
#   0.04125164 -0.09221578  0.0481941   0.02264075  0.11289164  0.01147584
#  -0.0716     -0.10598857 -0.04441489  0.0563578  -0.09462791 -0.06022105
#   0.01008237 -0.03599551 -0.04198597  0.03425174 -0.10493655  0.04886962
#  -0.04025583  0.06998791  0.00246998  0.07535643 -0.01901976 -0.05851745
#  -0.03649376  0.08005581 -0.0909299   0.09971938 -0.04951423 -0.11324841
#  -0.0323499  -0.02119342 -0.11298209 -0.02399936  0.08312243 -0.11404571
#   0.05339701  0.01654498 -0.04100841 -0.11183257  0.08396809  0.06478646
#  -0.04221564 -0.03993223 -0.08725706 -0.04700287  0.07405669 -0.0832556
#  -0.01024259 -0.05694208  0.05858723  0.07537473  0.04384744]
#
# Thetha 3 es:  [-0.11960096 -0.07037197 -0.09298313  0.11635423 -0.09072904  0.02342397
#   0.11193012  0.04320351 -0.01947665 -0.00942679 -0.09170946  0.0065042
#  -0.01971445 -0.05648134  0.00671846  0.10113214 -0.04491568  0.09718033
#  -0.0376256   0.02652992  0.07410247 -0.0138543   0.04608588 -0.0957259
#  -0.05444712  0.06903898  0.04622777  0.05378489 -0.07496644  0.0003011
#  -0.04909647  0.0808183  -0.08643436  0.11570052 -0.08202589  0.04191717
#   0.06663492 -0.09598769  0.04096366  0.00990796 -0.03326864  0.0251468
#   0.04571019 -0.02326816 -0.06345957  0.08456805  0.11357432 -0.06022997
#  -0.02785901 -0.11487024  0.06279199 -0.0029245  -0.0058095  -0.08238466
#   0.11410746 -0.11317368 -0.09475918  0.04311014 -0.07399791]
#
# Thetha 4 es:  [-0.08558388  0.10174368 -0.08376704 -0.00398691  0.10129116 -0.09963176
#  -0.07660496 -0.10015418  0.09319765  0.05534698  0.05863333  0.09589499
#   0.03867464 -0.07682027  0.06383204 -0.05561842 -0.02383498 -0.06917111
#  -0.0068243   0.06050537 -0.10424816 -0.07513353  0.04668654  0.11139285
#  -0.05366283 -0.10087625 -0.07836911 -0.05443104 -0.04814961  0.07703204
#  -0.06428405 -0.1188958   0.07371502  0.07157482  0.11153844 -0.11754238
#  -0.10304068 -0.09322925 -0.06866334  0.02015756  0.02988517  0.0908941
#  -0.11763214 -0.00590549  0.06438149  0.0553926  -0.01646889 -0.07298882
#   0.11106745  0.09352963  0.05570569 -0.08937199 -0.07629157 -0.09036232
#   0.08002648 -0.07884843  0.02777894 -0.08575594  0.05238956]
#
# Thetha 5 es:  [ 0.04920213  0.03192042 -0.06595644 -0.07966142 -0.09100076  0.02515814
#   0.07201537  0.03194967 -0.00979364 -0.11587791 -0.03213205  0.032075
#  -0.00439597  0.08859389 -0.03949155 -0.06122914 -0.05515547 -0.10827161
#  -0.09313311  0.03018258  0.0166874  -0.08724785 -0.03889917  0.11148762
#  -0.026482    0.05236435 -0.0534223   0.10498902 -0.01287714  0.02462344
#  -0.11044477  0.02594363 -0.03002482 -0.0250611  -0.04891682 -0.02669496
#  -0.04162576 -0.05246516 -0.03070023 -0.06449807 -0.01742827  0.09671581
#  -0.10089166  0.07438604 -0.03449314  0.10333809 -0.05678198 -0.0725789
#  -0.1124539  -0.08711329  0.06462718  0.01396136  0.11385123 -0.08860498
#  -0.02210675  0.03898359  0.09413236 -0.10417988  0.10390366]
#
# Thetha 6 es:  [-0.00843278 -0.0762992  -0.04375942 -0.11333227 -0.08585763  0.03310467
#  -0.07081915  0.1059814   0.07865732 -0.04827593  0.08180108 -0.05318003
#   0.10536583 -0.02962763 -0.10844161  0.07665576 -0.02906996 -0.05315959
#   0.07628298  0.04839604  0.09225624 -0.09452032  0.08730724 -0.09672679
#   0.05376104  0.01681773 -0.11471259 -0.09835036  0.11405294  0.11129547
#   0.09613096  0.03469003  0.09025041  0.02649313  0.07861098  0.04099299
#  -0.02511209  0.03078185  0.05995988 -0.06391722 -0.00990942 -0.11000393
#  -0.04734624 -0.00700688 -0.0710847   0.08137077  0.08403006 -0.11697817
#  -0.07384152 -0.08279124  0.00820733 -0.02476296  0.08825901  0.10588259
#  -0.10253172  0.04995224 -0.02250355  0.05731442 -0.02894585]
#
# Thetha 7 es:  [ 0.01346996  0.02009428  0.10729052 -0.07828373  0.01566068 -0.02043495
#  -0.11520823  0.08872251 -0.11539077 -0.04706429  0.10250621  0.04312707
#  -0.0346503  -0.04941606  0.05347092  0.09424344 -0.05415722  0.10275449
#  -0.10480928  0.01883115 -0.00322557  0.07291972  0.04260246  0.09892026
#   0.02192581  0.03157578  0.00187349  0.03184584  0.07686725  0.05269853
#  -0.08521175  0.08798751 -0.06727216 -0.08589095  0.06716391  0.0978332
#   0.06815323 -0.09497164  0.06097031 -0.11095676  0.01243166 -0.03169347
#  -0.08982845 -0.08494345 -0.01163632  0.10002475 -0.00703445 -0.09631554
#   0.07458666  0.00476249 -0.10400091  0.11403512  0.04847421 -0.01041426
#   0.07344845 -0.0573656  -0.05077625  0.01391982 -0.02054441]
#
# Thetha 8 es:  [ 0.10468352  0.02138294  0.01062567 -0.06602054 -0.10315771  0.06164749
#  -0.02179698 -0.00981861 -0.02287812 -0.04225082 -0.06763547 -0.06571282
#   0.02289281  0.017254   -0.01292689 -0.03764119 -0.0604225  -0.09308528
#  -0.10827871  0.09517214  0.07405899  0.06091669 -0.0717467   0.03612181
#  -0.0816152  -0.07776575 -0.03003921 -0.07027578 -0.01707688  0.07642986
#   0.11042357 -0.03638962 -0.02015615  0.08896342 -0.09436824 -0.11032721
#   0.09320024  0.02314434 -0.09112102 -0.02422342  0.05026792  0.04014791
#   0.08062533 -0.08653725 -0.0924884   0.09013962  0.05283927 -0.04049679
#   0.03483138  0.11526572 -0.05126577  0.11094115  0.05704301  0.08911662
#  -0.09627857 -0.11611787  0.09336084  0.08331354  0.0233214 ]

# %%
for i in range(len(Theta2)):
    print("Thetha",i,"es: ", Theta1[i])
    print("")
# Out:
# Thetha 0 es:  [ 0.00689772  0.09217307 -0.09894664  0.09456197 -0.08253116 -0.08711445
#   0.11437279 -0.04450613 -0.00505212 -0.1175531   0.00890481 -0.11531673
#   0.10688457  0.07020571 -0.11736101  0.02390581  0.10705661  0.10275758
#   0.10090868 -0.06067839  0.09995444  0.07882862  0.07559065 -0.01060503
#   0.04419121 -0.05407899 -0.04315506  0.09466233 -0.01565307  0.02087181
#   0.0742021   0.07451553  0.07375455 -0.10016464 -0.00884323 -0.02252134
#  -0.05477311 -0.0530116   0.10681123  0.09436004  0.10992021 -0.00305563
#  -0.00417708  0.07217276 -0.06573479  0.00945167  0.11387754  0.05479473
#  -0.02392123  0.0857498  -0.07615058  0.08041883 -0.10939324  0.10291206
#   0.0241693  -0.04186985  0.04769836  0.04822406  0.10786122]
#
# Thetha 1 es:  [-0.08242108  0.03538628 -0.00107819  0.06568612  0.03998907 -0.05489562
#   0.00638213 -0.06062198 -0.11565901 -0.08661602  0.05845594 -0.00278417
#   0.08119536 -0.02928327  0.03919074 -0.03795501  0.02612297 -0.00748384
#  -0.11071147  0.04570384 -0.01377614 -0.01783007  0.1028155   0.00102276
#   0.08699947 -0.00076932 -0.11334463 -0.10833024  0.0293514   0.05290898
#   0.09033783 -0.01619186 -0.08161601 -0.07425662 -0.0053241  -0.07885253
#   0.08156005  0.01887726 -0.1142183   0.01029229 -0.06624307  0.02711869
#   0.00937818  0.09188667  0.08057692 -0.06695954  0.04606969 -0.03704442
#  -0.09687921 -0.11879015 -0.07171636  0.08758921 -0.11232753  0.06932909
#   0.05258098  0.01757279 -0.00314975 -0.01869647 -0.03928417]
#
# Thetha 2 es:  [ 0.09801734  0.00681138  0.08729173 -0.08838256 -0.02009613  0.08473725
#   0.04125164 -0.09221578  0.0481941   0.02264075  0.11289164  0.01147584
#  -0.0716     -0.10598857 -0.04441489  0.0563578  -0.09462791 -0.06022105
#   0.01008237 -0.03599551 -0.04198597  0.03425174 -0.10493655  0.04886962
#  -0.04025583  0.06998791  0.00246998  0.07535643 -0.01901976 -0.05851745
#  -0.03649376  0.08005581 -0.0909299   0.09971938 -0.04951423 -0.11324841
#  -0.0323499  -0.02119342 -0.11298209 -0.02399936  0.08312243 -0.11404571
#   0.05339701  0.01654498 -0.04100841 -0.11183257  0.08396809  0.06478646
#  -0.04221564 -0.03993223 -0.08725706 -0.04700287  0.07405669 -0.0832556
#  -0.01024259 -0.05694208  0.05858723  0.07537473  0.04384744]
#
# Thetha 3 es:  [-0.11960096 -0.07037197 -0.09298313  0.11635423 -0.09072904  0.02342397
#   0.11193012  0.04320351 -0.01947665 -0.00942679 -0.09170946  0.0065042
#  -0.01971445 -0.05648134  0.00671846  0.10113214 -0.04491568  0.09718033
#  -0.0376256   0.02652992  0.07410247 -0.0138543   0.04608588 -0.0957259
#  -0.05444712  0.06903898  0.04622777  0.05378489 -0.07496644  0.0003011
#  -0.04909647  0.0808183  -0.08643436  0.11570052 -0.08202589  0.04191717
#   0.06663492 -0.09598769  0.04096366  0.00990796 -0.03326864  0.0251468
#   0.04571019 -0.02326816 -0.06345957  0.08456805  0.11357432 -0.06022997
#  -0.02785901 -0.11487024  0.06279199 -0.0029245  -0.0058095  -0.08238466
#   0.11410746 -0.11317368 -0.09475918  0.04311014 -0.07399791]
#
# Thetha 4 es:  [-0.08558388  0.10174368 -0.08376704 -0.00398691  0.10129116 -0.09963176
#  -0.07660496 -0.10015418  0.09319765  0.05534698  0.05863333  0.09589499
#   0.03867464 -0.07682027  0.06383204 -0.05561842 -0.02383498 -0.06917111
#  -0.0068243   0.06050537 -0.10424816 -0.07513353  0.04668654  0.11139285
#  -0.05366283 -0.10087625 -0.07836911 -0.05443104 -0.04814961  0.07703204
#  -0.06428405 -0.1188958   0.07371502  0.07157482  0.11153844 -0.11754238
#  -0.10304068 -0.09322925 -0.06866334  0.02015756  0.02988517  0.0908941
#  -0.11763214 -0.00590549  0.06438149  0.0553926  -0.01646889 -0.07298882
#   0.11106745  0.09352963  0.05570569 -0.08937199 -0.07629157 -0.09036232
#   0.08002648 -0.07884843  0.02777894 -0.08575594  0.05238956]
#
# Thetha 5 es:  [ 0.04920213  0.03192042 -0.06595644 -0.07966142 -0.09100076  0.02515814
#   0.07201537  0.03194967 -0.00979364 -0.11587791 -0.03213205  0.032075
#  -0.00439597  0.08859389 -0.03949155 -0.06122914 -0.05515547 -0.10827161
#  -0.09313311  0.03018258  0.0166874  -0.08724785 -0.03889917  0.11148762
#  -0.026482    0.05236435 -0.0534223   0.10498902 -0.01287714  0.02462344
#  -0.11044477  0.02594363 -0.03002482 -0.0250611  -0.04891682 -0.02669496
#  -0.04162576 -0.05246516 -0.03070023 -0.06449807 -0.01742827  0.09671581
#  -0.10089166  0.07438604 -0.03449314  0.10333809 -0.05678198 -0.0725789
#  -0.1124539  -0.08711329  0.06462718  0.01396136  0.11385123 -0.08860498
#  -0.02210675  0.03898359  0.09413236 -0.10417988  0.10390366]

# %% [markdown]
# ## Funcion para realizar predicciones
#
# Predecir la salida de una entrada dada una red neuronal entrenada, Genera la salida prevista de X dados los pesos entrenados de un neural

# %%
def predict(Theta1, Theta2, X):

    # Compute the output using the trained weights
    h1 = np.dot(np.concatenate([np.ones((X.shape[0], 1)), X], axis=1), Theta1.T)
    output = np.dot(np.concatenate([np.ones((h1.shape[0], 1)), h1], axis=1), Theta2.T)

    return output

# %%
#Creamos la matriz con 6 ejemplos para hacer la prueba predecir un precio de cada ejemplo:

# Supongamos que tienes tus datos de prueba en una variable llamada X_test
# X_test debe contener los mismos tipos de características que utilizaste para entrenar tu modelo
# Normaliza los datos de prueba utilizando mu y sigma calculados previamente
X_test_normalized = (X_test - mu) / sigma

# Calcula las predicciones para los datos de prueba
predicciones = predict(Theta1, Theta2, X_test_normalized)

# Imprime las predicciones
print("Las predicciones para los datos de prueba son:")
for i in range(len(X_test)):
    print("Para el ejemplo ", i+1, " es:", predicciones[i])
    print("")
# Out:
# Las predicciones para los datos de prueba son:
# Para el ejemplo  1  es: [ 0.03528969 -0.02267964  0.08606047 -0.17507653 -0.03452739 -0.24243824]
#
# Para el ejemplo  2  es: [ 0.09738966 -0.10525736  0.11474203 -0.08586016 -0.01496303 -0.03885458]
#
# Para el ejemplo  3  es: [ 0.16560013  0.04974468  0.04679299 -0.01027123  0.01120355 -0.09155991]
#
# Para el ejemplo  4  es: [ 0.17693294  0.19258444 -0.00361454  0.04783708 -0.01256938 -0.04201062]
#
# Para el ejemplo  5  es: [ 0.21502653  0.03472737  0.10568027 -0.04486666 -0.00643499 -0.0991083 ]
#
# Para el ejemplo  6  es: [ 0.07027357 -0.02172677  0.08580655  0.01914144 -0.15130686  0.13496285]
#
# Para el ejemplo  7  es: [ 0.26331291 -0.1131191  -0.00026638 -0.11508474 -0.10575395 -0.14073949]
#
# Para el ejemplo  8  es: [ 0.10006281 -0.09758014  0.10170328 -0.20895244 -0.10344542 -0.17111784]
#
# Para el ejemplo  9  es: [ 0.02172874  0.00623563  0.06847268  0.0993397  -0.05517789  0.07265127]
#
# Para el ejemplo  10  es: [-0.10292378 -0.13845114  0.18716653 -0.11597128 -0.04970034  0.00852039]
#
# Para el ejemplo  11  es: [ 0.0167784  -0.00737857  0.17620675  0.06953895 -0.00967994  0.11815987]
#
# Para el ejemplo  12  es: [ 0.09977312 -0.01141066  0.10658612 -0.05130635 -0.0842389  -0.01664803]
#
# Para el ejemplo  13  es: [ 0.12686566 -0.06277125  0.05513605 -0.07362283 -0.06994922 -0.14121369]
#
# Para el ejemplo  14  es: [ 0.14293573 -0.00653381  0.03385336 -0.06363746  0.11563662 -0.17575584]
#
# Para el ejemplo  15  es: [-0.0104411  -0.11607049  0.26629815 -0.22084766 -0.1362584  -0.02341629]
#
# Para el ejemplo  16  es: [-0.03529666 -0.16229699  0.13369388 -0.19764512 -0.1342994  -0.13742448]
#
# Para el ejemplo  17  es: [ 0.25010106  0.25826764  0.10389782  0.10291804 -0.03028312  0.12185834]
#
# Para el ejemplo  18  es: [ 0.1292563  -0.16547893  0.01135446 -0.03476656 -0.02662091 -0.18646256]
#
# Para el ejemplo  19  es: [ 0.08093428 -0.10523185  0.19419837 -0.1492404  -0.12355677  0.03781063]
#
# Para el ejemplo  20  es: [ 0.0510995   0.1135353  -0.01870302  0.16525614  0.17362911 -0.08543952]
#
# Para el ejemplo  21  es: [-0.16229557 -0.05608487  0.2018358   0.03363729  0.06031561  0.02366441]
#
# Para el ejemplo  22  es: [ 0.03931869 -0.13596279  0.08788198 -0.05557801 -0.05862846 -0.05396447]
#
# Para el ejemplo  23  es: [ 0.1901379   0.03697669  0.07783992 -0.12696602 -0.07914112 -0.12446284]
#
# Para el ejemplo  24  es: [ 0.10726187 -0.0863519   0.19602362 -0.29688363 -0.18938977 -0.02882766]
#
# Para el ejemplo  25  es: [ 0.01812886 -0.22803027  0.06139458  0.01954727 -0.16339757  0.19406837]
#
# Para el ejemplo  26  es: [-0.03404046 -0.09490975  0.16087404  0.00401054 -0.080414    0.09488806]
#
# Para el ejemplo  27  es: [ 0.04888953  0.02805676  0.07778856 -0.12165585 -0.0441718  -0.18399555]
#
# Para el ejemplo  28  es: [ 0.22072931 -0.03550087  0.0006622  -0.04263378  0.0066697  -0.12201581]
#
# Para el ejemplo  29  es: [ 0.16225961 -0.08990781  0.06037742 -0.08155599 -0.03872546 -0.10750726]
#
# Para el ejemplo  30  es: [ 0.10385189 -0.0315033   0.06818979 -0.09413771 -0.01970176 -0.195737  ]
#
# Para el ejemplo  31  es: [ 0.18201415  0.03740879  0.02888564 -0.06354003  0.03574798 -0.19775491]
#
# Para el ejemplo  32  es: [ 0.16324849 -0.1057542   0.00898102 -0.11775346 -0.10180362 -0.1440303 ]
#
# Para el ejemplo  33  es: [ 0.23744608  0.27509933  0.11297738  0.02280768  0.17121589 -0.10192363]
#
# Para el ejemplo  34  es: [ 0.1703265  -0.02545579  0.14604188 -0.07507457 -0.06777449  0.02074603]
#
# Para el ejemplo  35  es: [-0.13864773 -0.35122295  0.09914296 -0.18778923 -0.07625146 -0.15566799]
#
# Para el ejemplo  36  es: [ 0.12420802  0.00756922  0.13487797 -0.06452676 -0.2203014   0.08813544]
#
# Para el ejemplo  37  es: [ 0.22687508 -0.06369883  0.09091276 -0.19112698 -0.11782892 -0.18994421]
#
# Para el ejemplo  38  es: [-0.0422256  -0.07106633  0.11250709 -0.19298114 -0.08491458 -0.21196574]
#
# Para el ejemplo  39  es: [ 0.0015714   0.18342372  0.1369504   0.05356487 -0.00573902  0.03301311]
#
# Para el ejemplo  40  es: [0.07425156 0.35451307 0.13024468 0.25791652 0.12695899 0.17512029]
#
# Para el ejemplo  41  es: [ 0.25180626  0.09461024  0.00164973  0.03511068  0.05515811 -0.11108681]
#
# Para el ejemplo  42  es: [ 0.2099959  -0.28219302 -0.03856957 -0.19689149 -0.20846573 -0.17951632]
#
# Para el ejemplo  43  es: [ 0.16671042 -0.16444109  0.04837065 -0.04266981 -0.12771137 -0.02810333]
#
# Para el ejemplo  44  es: [ 0.14128893  0.08487912  0.00712632  0.04893387 -0.03812615  0.00485778]
#
# Para el ejemplo  45  es: [ 0.09644577  0.01924779  0.06105522  0.07829339  0.04315841 -0.00428567]
#
# Para el ejemplo  46  es: [ 0.03693685 -0.21573553  0.0806141  -0.10797474  0.07552259 -0.32947503]
#
# Para el ejemplo  47  es: [ 0.13347923 -0.11389803  0.04487967 -0.12057714 -0.10821146 -0.03939306]
#
# Para el ejemplo  48  es: [ 0.10260823 -0.22461534  0.19775675 -0.29465066 -0.02388382 -0.26893255]
#
# Para el ejemplo  49  es: [ 0.19565846  0.28838767  0.0959353   0.06539779  0.05877195 -0.08205733]
#
# Para el ejemplo  50  es: [-0.00098673 -0.203759    0.22675446 -0.33098598 -0.15084102 -0.2032043 ]
#
# Para el ejemplo  51  es: [ 0.02277746 -0.08077962  0.15759497 -0.26613902 -0.09267489 -0.17342216]
#
# Para el ejemplo  52  es: [0.06693101 0.00805099 0.139329   0.13061511 0.00297988 0.14128679]
#
# Para el ejemplo  53  es: [ 0.11775887 -0.14825483  0.09930511 -0.18449976  0.0358478  -0.24947798]
#
# Para el ejemplo  54  es: [ 0.07198569 -0.18260452  0.03485484 -0.1024858  -0.01160902 -0.1081256 ]
#
# Para el ejemplo  55  es: [-0.19065322 -0.41776258  0.09900866 -0.21724588 -0.15458406 -0.15987286]
#
# Para el ejemplo  56  es: [ 0.09640067 -0.2268981   0.11093832 -0.26884536 -0.08026656 -0.23439303]
#
# Para el ejemplo  57  es: [ 0.25812561 -0.01595481  0.06084715 -0.07927524  0.02644174 -0.20854188]
#
# Para el ejemplo  58  es: [ 0.07748591 -0.04204956  0.04090027  0.04563202  0.12105845 -0.17603772]
#
# Para el ejemplo  59  es: [ 0.12732812  0.00720906  0.06758665  0.00892137 -0.00099842 -0.03003096]
#
# Para el ejemplo  60  es: [ 0.33616636  0.07542446  0.01471892 -0.02948942 -0.03582106 -0.12814865]
#
# Para el ejemplo  61  es: [0.19641432 0.1200149  0.03142773 0.05968669 0.02390423 0.00783549]
#
# Para el ejemplo  62  es: [0.05908448 0.13653151 0.187021   0.10721308 0.06567818 0.12297702]
#
# Para el ejemplo  63  es: [ 0.00827129 -0.33607189  0.15970014 -0.25337257 -0.26304315 -0.02092858]
#
# Para el ejemplo  64  es: [ 0.09661499 -0.24479399  0.08455984 -0.18462796 -0.1185764  -0.17789137]
#
# Para el ejemplo  65  es: [ 0.10261631 -0.11210895  0.05615578 -0.19462491 -0.18684605 -0.08211161]
#
# Para el ejemplo  66  es: [ 0.19369847 -0.17505815  0.03662037 -0.2181519  -0.07710221 -0.22664715]
#
# Para el ejemplo  67  es: [ 0.06203728 -0.13153817  0.09197622 -0.0450693   0.0020604  -0.12498936]
#
# Para el ejemplo  68  es: [-0.18307115 -0.1420796   0.26980056 -0.08549387 -0.04783996  0.0416105 ]
#
# Para el ejemplo  69  es: [-0.03428641 -0.15062254  0.13074364 -0.03145411 -0.03030784 -0.02763933]
#
# Para el ejemplo  70  es: [ 0.01971168 -0.08522658  0.17039462 -0.19315501 -0.01174814 -0.17605533]
#
# Para el ejemplo  71  es: [-0.02253153 -0.22775679  0.14453169 -0.26499016 -0.11093645 -0.16235382]
#
# Para el ejemplo  72  es: [ 0.08330926 -0.17540538 -0.00219918 -0.06957838  0.0154927  -0.2425082 ]
#
# Para el ejemplo  73  es: [-0.00202018 -0.05433203  0.12574893 -0.02206246 -0.04106057  0.04019494]
#
# Para el ejemplo  74  es: [ 0.16361625 -0.17809646 -0.00886978 -0.2173192  -0.19010264 -0.16082696]
#
# Para el ejemplo  75  es: [ 0.1315948   0.09460434  0.06941406  0.00614697  0.02197357 -0.02143233]
#
# Para el ejemplo  76  es: [ 0.15974431 -0.01781363  0.10280304 -0.03911034 -0.13588477  0.0679753 ]
#
# Para el ejemplo  77  es: [-0.07755999 -0.23108048  0.16696301 -0.22531164 -0.07223417 -0.20120746]
#
# Para el ejemplo  78  es: [ 0.21272011  0.01872116  0.00490321  0.08667553  0.00351145 -0.08629409]
#
# Para el ejemplo  79  es: [ 0.00370777 -0.01571566  0.04855364 -0.0942854  -0.10323093 -0.06162736]
#
# Para el ejemplo  80  es: [ 0.17216127  0.01828995  0.14060989 -0.04153267 -0.0859397   0.08465265]
#
# Para el ejemplo  81  es: [-0.01933232 -0.32238183  0.10860843 -0.27289381 -0.18110555 -0.16832642]
#
# Para el ejemplo  82  es: [-0.04887104 -0.30529144  0.196065   -0.28502346 -0.17939554 -0.13380207]
#
# Para el ejemplo  83  es: [ 0.13091306  0.01340151  0.05364669 -0.12384645  0.03264549 -0.26685096]
#
# Para el ejemplo  84  es: [-0.01368223 -0.27693001  0.04103436 -0.17265602 -0.16900908 -0.13561693]
#
# Para el ejemplo  85  es: [ 0.20130242  0.30587399  0.00873699  0.08283379 -0.06070221  0.08095279]
#
# Para el ejemplo  86  es: [ 0.12358928 -0.07375698  0.11292572 -0.16081855 -0.11660966 -0.05165512]
#
# Para el ejemplo  87  es: [ 0.15978038  0.02242544  0.1434108  -0.1148483  -0.15283919  0.03251311]
#
# Para el ejemplo  88  es: [-0.01483316 -0.13018291  0.13079836 -0.21291025 -0.01913817 -0.1937453 ]
#
# Para el ejemplo  89  es: [ 0.09107326  0.02570309  0.04489982  0.10375318 -0.03995636  0.00835245]
#
# Para el ejemplo  90  es: [-0.0146808  -0.08719009  0.18166975 -0.09657581 -0.08974186  0.00276843]
#
# Para el ejemplo  91  es: [ 0.08877989 -0.18028785  0.18640125 -0.09449092 -0.25528059  0.13194373]
#
# Para el ejemplo  92  es: [ 0.05228933 -0.10433861 -0.03051977 -0.13150082 -0.1076046  -0.26259088]
#
# Para el ejemplo  93  es: [ 0.10560524  0.02545261 -0.04235889  0.06087194 -0.00055235 -0.03517451]
#
# Para el ejemplo  94  es: [ 0.07200284 -0.02659036  0.18838763 -0.12219396 -0.02220432 -0.07245313]
#
# Para el ejemplo  95  es: [ 0.08875757  0.00794634  0.20562069 -0.11967317 -0.09840147  0.04771371]
#
# Para el ejemplo  96  es: [ 0.04990883 -0.09876192  0.06135845 -0.08636099 -0.06275335 -0.15715541]
#
# Para el ejemplo  97  es: [ 0.02127376 -0.0776533   0.04533195 -0.17102701 -0.07088821 -0.30537317]
#
# Para el ejemplo  98  es: [ 0.00543848 -0.03504187  0.19416517  0.08671209 -0.04491163  0.16634149]
#
# Para el ejemplo  99  es: [ 0.11982319  0.15998411  0.0870739  -0.04010669 -0.05361675  0.07015053]
#
# Para el ejemplo  100  es: [ 0.20083611 -0.10843218  0.03383333 -0.11069189  0.07245659 -0.24159623]
#
# Para el ejemplo  101  es: [ 0.17883379 -0.12155719 -0.01129273  0.02858936  0.03770754 -0.09814931]
#
# Para el ejemplo  102  es: [ 0.02999407  0.07122934  0.17574033 -0.1141204  -0.05892751 -0.01678937]
#
# Para el ejemplo  103  es: [ 0.27022819 -0.0948038   0.13435693 -0.27129829 -0.24143802 -0.06104316]
#
# Para el ejemplo  104  es: [ 0.01627448 -0.11967176  0.03202466 -0.053262   -0.0446521  -0.20012446]
#
# Para el ejemplo  105  es: [ 0.00558136 -0.0140444   0.24359454 -0.20083472 -0.01738129 -0.12410608]
#
# Para el ejemplo  106  es: [-0.05760735 -0.18404038  0.09323996 -0.01276506  0.00548005 -0.1027315 ]
#
# Para el ejemplo  107  es: [ 0.16237139 -0.01600851  0.09086593 -0.06800258 -0.03991481 -0.08220142]
#
# Para el ejemplo  108  es: [-0.01417007 -0.00902801  0.15430578  0.03403133  0.01677719  0.00625235]
#
# Para el ejemplo  109  es: [ 0.18958214 -0.00171272  0.05747424 -0.03478379 -0.04915997 -0.03112112]
#
# Para el ejemplo  110  es: [ 0.1186222  -0.02514066  0.12589259 -0.078681   -0.08787477 -0.08700327]
#
# Para el ejemplo  111  es: [ 0.04848999  0.17566929  0.12769641 -0.02429069 -0.01175761 -0.00631302]
#
# Para el ejemplo  112  es: [ 0.1044931  -0.05272237  0.02812461  0.05155787 -0.07646405  0.0415624 ]
#
# Para el ejemplo  113  es: [-0.03171874 -0.22729343  0.23812792 -0.23963316 -0.15069741 -0.06572142]
#
# Para el ejemplo  114  es: [ 0.14629897  0.06016365  0.06354474 -0.09882252 -0.08082658 -0.08953369]
#
# Para el ejemplo  115  es: [-0.03947899 -0.01720712  0.25709452 -0.17254824 -0.01292692 -0.10351541]
#
# Para el ejemplo  116  es: [ 0.10624113  0.02821181  0.21895252 -0.07832218 -0.07721605  0.006644  ]
#
# Para el ejemplo  117  es: [0.1160335  0.01291529 0.01071012 0.12913573 0.00789049 0.04341493]
#
# Para el ejemplo  118  es: [ 0.00443521  0.10437176  0.16632036  0.10493366 -0.05609979  0.1954841 ]
#
# Para el ejemplo  119  es: [ 0.21586468  0.05649291  0.0022269  -0.16723156  0.01247497 -0.25834972]
#
# Para el ejemplo  120  es: [ 0.05183459  0.00611016  0.07724754  0.04176687  0.07011209 -0.12536751]
#
# Para el ejemplo  121  es: [ 0.25304108  0.09645874 -0.01784385 -0.01473481 -0.09308538 -0.026917  ]
#
# Para el ejemplo  122  es: [-0.12200912 -0.20176348  0.13720413 -0.23020671 -0.07558218 -0.25095903]
#
# Para el ejemplo  123  es: [ 0.09978891 -0.01558872  0.05680584  0.16958871 -0.03918999  0.19048395]
#
# Para el ejemplo  124  es: [ 0.10026705  0.14525218  0.11953633 -0.04711658 -0.12528724  0.06221389]
#
# Para el ejemplo  125  es: [ 0.02983045 -0.07274018  0.13653562 -0.17777223 -0.17602583 -0.047689  ]
#
# Para el ejemplo  126  es: [ 0.11209843 -0.23205469  0.07018391 -0.17090246 -0.18730111 -0.13227778]
#
# Para el ejemplo  127  es: [ 0.19404169  0.18874806  0.04264473  0.0272583   0.09150556 -0.18696331]
#
# Para el ejemplo  128  es: [-0.14356388 -0.05316141  0.20726054 -0.11253385 -0.02586489 -0.13616389]
#
# Para el ejemplo  129  es: [ 0.12233593 -0.09958127  0.04155899  0.01783443  0.03732904 -0.09636989]
#
# Para el ejemplo  130  es: [ 0.15691855 -0.2591427   0.06719784 -0.2190619  -0.08320966 -0.21356189]
#
# Para el ejemplo  131  es: [ 0.055634   -0.07115957  0.09287631 -0.03395147 -0.11957511  0.03955642]
#
# Para el ejemplo  132  es: [ 0.41309692  0.18756002 -0.14559803  0.07075184  0.10484731 -0.27053692]
#
# Para el ejemplo  133  es: [0.06120399 0.2499819  0.05427069 0.27191665 0.05036761 0.19772268]
#
# Para el ejemplo  134  es: [-0.05130007 -0.18088935  0.1682762  -0.12877843 -0.079072   -0.08885581]
#
# Para el ejemplo  135  es: [ 0.30804956  0.1434076  -0.00893682  0.00330036  0.09403977 -0.16403803]
#
# Para el ejemplo  136  es: [ 0.05998215 -0.01242981  0.23643611 -0.24679591 -0.17209062  0.03249344]
#
# Para el ejemplo  137  es: [ 0.10119585  0.00538664  0.19335687 -0.17115113  0.0432406  -0.18643402]
#
# Para el ejemplo  138  es: [-0.03731009 -0.24997171  0.20370294 -0.27336228 -0.2201357  -0.08722658]
#
# Para el ejemplo  139  es: [ 0.1607266  -0.05135186  0.00634646 -0.19670813 -0.04225397 -0.30023262]
#
# Para el ejemplo  140  es: [ 0.00165663 -0.11459205  0.11501557 -0.09794186 -0.12009546 -0.0041256 ]
#
# Para el ejemplo  141  es: [ 0.07158275 -0.25857332  0.07000095 -0.10952965 -0.13723973 -0.04747481]
#
# Para el ejemplo  142  es: [ 0.13653137 -0.26569182 -0.00736216 -0.08497225 -0.11037904 -0.13979963]
#
# Para el ejemplo  143  es: [ 0.06289782 -0.14722556  0.05361388 -0.18570395 -0.08725963 -0.16617338]
#
# Para el ejemplo  144  es: [-0.00430283 -0.15729241  0.08400425 -0.23739165 -0.03299595 -0.30410282]
#
# Para el ejemplo  145  es: [ 0.01397578 -0.13130911  0.14577547 -0.1065998   0.09199433 -0.24881967]
#
# Para el ejemplo  146  es: [ 0.11832794 -0.15786964  0.17828454 -0.1300419  -0.10215251 -0.01889787]
#
# Para el ejemplo  147  es: [ 0.10986437 -0.12542889  0.05958697 -0.15822342 -0.08978089 -0.16150359]
#
# Para el ejemplo  148  es: [ 0.31072667  0.17549655  0.01284526  0.0574893   0.05179616 -0.03005781]
#
# Para el ejemplo  149  es: [ 0.11489347  0.2581287   0.15907417  0.24590099 -0.00901725  0.26829968]
#
# Para el ejemplo  150  es: [ 0.03087808 -0.18408629  0.10482512 -0.10965448 -0.13620589 -0.10338414]
#
# Para el ejemplo  151  es: [0.23602181 0.13584115 0.00651399 0.13389841 0.07821108 0.029329  ]
#
# Para el ejemplo  152  es: [ 0.13654544  0.15683252  0.15006661  0.07853392 -0.01609735  0.0585529 ]
#
# Para el ejemplo  153  es: [ 0.22329995  0.17111269 -0.01662751  0.12668533 -0.05991768  0.01392164]
#
# Para el ejemplo  154  es: [ 0.11989737 -0.03807647  0.07516431 -0.18143257  0.03863687 -0.24776247]
#
# Para el ejemplo  155  es: [ 0.01127832 -0.17226584  0.19036121 -0.29086355 -0.11526336 -0.16369325]
#
# Para el ejemplo  156  es: [ 0.29157297  0.11242527 -0.04837334  0.20185465  0.06894826  0.00574396]
#
# Para el ejemplo  157  es: [ 0.23420203 -0.07340021  0.0441683  -0.21683761 -0.15268531 -0.17523354]
#
# Para el ejemplo  158  es: [-0.00826973 -0.10679768  0.06748365 -0.09663251  0.07297713 -0.30424743]
#
# Para el ejemplo  159  es: [-0.01119001 -0.11474769  0.11829069 -0.13611243  0.03626369 -0.15633181]
#
# Para el ejemplo  160  es: [ 6.86481719e-02  6.86854242e-02  5.74401011e-02  8.03241260e-02
#  -1.22937574e-02  3.74949949e-05]
#
# Para el ejemplo  161  es: [ 0.05753349 -0.00491445  0.12164466 -0.04896738 -0.00419294 -0.02989993]
#
# Para el ejemplo  162  es: [ 0.1862692   0.01242136  0.05706647  0.03295407  0.05638859 -0.05022949]
#
# Para el ejemplo  163  es: [ 0.15844358 -0.11419936  0.12964616 -0.30546438 -0.16460576 -0.16506209]
#
# Para el ejemplo  164  es: [ 0.19582017  0.06226534  0.07446438 -0.17361289 -0.03860949 -0.23857078]
#
# Para el ejemplo  165  es: [ 0.11903677 -0.08544886  0.04683044 -0.06559169 -0.05526931 -0.05951471]
#
# Para el ejemplo  166  es: [ 0.1003892  -0.06957263  0.14046572 -0.17154318 -0.11714591 -0.14724781]
#
# Para el ejemplo  167  es: [ 0.0605584  -0.25851297  0.16788551 -0.37602839 -0.22289237 -0.22488806]
#
# Para el ejemplo  168  es: [ 0.12976254  0.02501197  0.16283305 -0.13809458 -0.10156156 -0.04729479]
#
# Para el ejemplo  169  es: [ 0.13045207 -0.16165985 -0.00124267 -0.118981    0.03672744 -0.26777672]
#
# Para el ejemplo  170  es: [ 0.21234873  0.23057999  0.06789464  0.03313232 -0.02949756 -0.01688219]
#
# Para el ejemplo  171  es: [0.26947784 0.30679325 0.07575057 0.19932318 0.06182132 0.10636943]
#
# Para el ejemplo  172  es: [ 0.22333147 -0.07444225 -0.00262191  0.01635435 -0.00292676 -0.0914765 ]
#
# Para el ejemplo  173  es: [ 0.06507837  0.06024136  0.06334082  0.07346485  0.10776455 -0.08520332]
#
# Para el ejemplo  174  es: [ 0.23712078  0.08487212  0.13176177 -0.09834405 -0.04572743 -0.07637919]
#
# Para el ejemplo  175  es: [ 0.25054264 -0.0757239   0.08013259 -0.12986781 -0.03831994 -0.11233844]
#
# Para el ejemplo  176  es: [ 0.28374901 -0.05958224 -0.04812242 -0.18902887 -0.12357155 -0.26201097]
#
# Para el ejemplo  177  es: [-0.10076076 -0.25553529  0.13880989 -0.05085675 -0.00041055 -0.0460375 ]
#
# Para el ejemplo  178  es: [ 0.13485169  0.00162496  0.03108888  0.051148   -0.0419085   0.007953  ]
#
# Para el ejemplo  179  es: [ 0.0528357  -0.18443556  0.09362873 -0.18500149 -0.11749123 -0.13945931]
#
# Para el ejemplo  180  es: [-0.01786098  0.00714636  0.1796592  -0.10151872 -0.07917973 -0.01849425]
#
# Para el ejemplo  181  es: [ 0.11230909 -0.17411599  0.09319708 -0.17560558 -0.05772572 -0.2176063 ]
#
# Para el ejemplo  182  es: [-0.01077243 -0.09167924  0.14312564 -0.05173748 -0.02922358  0.00143582]
#
# Para el ejemplo  183  es: [ 0.10537559  0.04682996  0.09852221 -0.02992407  0.01358873 -0.18037054]
#
# Para el ejemplo  184  es: [ 0.11999049 -0.00871427  0.04603246 -0.09870711 -0.11529993 -0.06962977]
#
# Para el ejemplo  185  es: [ 0.29482679 -0.07918023 -0.05924475 -0.0310244   0.05858492 -0.27559571]
#
# Para el ejemplo  186  es: [ 0.13413743 -0.06437895  0.12402233 -0.05427262 -0.30550837  0.24862458]
#
# Para el ejemplo  187  es: [ 0.17561555 -0.02745433  0.0563819   0.09724016 -0.04767187  0.03934246]
#
# Para el ejemplo  188  es: [ 0.04452079 -0.16452519  0.14678955 -0.3207897  -0.25297387 -0.06457098]
#
# Para el ejemplo  189  es: [ 0.01496859 -0.06773734  0.18424415 -0.19143932 -0.15007257 -0.03627286]
#
# Para el ejemplo  190  es: [ 0.04938038 -0.11410966  0.23691665 -0.15857001 -0.03041666  0.01885023]
#
# Para el ejemplo  191  es: [ 0.02456069  0.06748227  0.15447973 -0.14148577 -0.03105293 -0.04728406]
#
# Para el ejemplo  192  es: [ 0.32384819 -0.07365942  0.05007811 -0.13158569 -0.11677775 -0.17486956]
#
# Para el ejemplo  193  es: [-0.03921297 -0.17419809  0.10648328 -0.1522022  -0.08155298 -0.18050756]
#
# Para el ejemplo  194  es: [ 0.09532838  0.0364891   0.05448534 -0.15937726  0.13068186 -0.4178703 ]
#
# Para el ejemplo  195  es: [ 0.0415474   0.00914969  0.17433141 -0.14654075 -0.10489796 -0.08310916]
#
# Para el ejemplo  196  es: [ 0.04005648 -0.07432814  0.06985237 -0.21213764 -0.15905504 -0.1334807 ]
#
# Para el ejemplo  197  es: [-0.05900691 -0.09029445  0.13030586 -0.13885935 -0.08254297 -0.12703701]
#
# Para el ejemplo  198  es: [ 0.04025531  0.04037396  0.13897267  0.03712136 -0.12094773  0.0883536 ]
#
# Para el ejemplo  199  es: [ 0.06841296  0.12412084  0.18923478 -0.06293034  0.03912166 -0.05135902]
#
# Para el ejemplo  200  es: [ 0.07541396 -0.26548658  0.00844874 -0.11968718 -0.16356803 -0.12410373]
#
# Para el ejemplo  201  es: [ 0.20640991 -0.02044706  0.00375447  0.05073154 -0.03412523 -0.06596561]
#
# Para el ejemplo  202  es: [-0.06951741 -0.29133405  0.1490171  -0.05282459 -0.03040777  0.03448723]
#
# Para el ejemplo  203  es: [ 0.03578165  0.06356981  0.14761808 -0.02084995 -0.07381536  0.01909002]
#
# Para el ejemplo  204  es: [0.0825637  0.12868325 0.10915044 0.17063927 0.13383837 0.08570884]
#
# Para el ejemplo  205  es: [ 0.09608116 -0.21619406  0.05476408  0.00787364 -0.12941138  0.03185555]
#
# Para el ejemplo  206  es: [-0.01895289  0.16104192  0.08938104  0.01015677  0.03183152 -0.08230089]
#
# Para el ejemplo  207  es: [ 0.24281011 -0.03375408  0.04697877  0.00364704 -0.03508815 -0.04620269]
#
# Para el ejemplo  208  es: [ 0.06391256 -0.20062855  0.03879983 -0.12765927 -0.11520036 -0.15538307]
#
# Para el ejemplo  209  es: [ 0.01742684 -0.26529621  0.04783115 -0.15280641 -0.18252578 -0.07998629]
#
# Para el ejemplo  210  es: [-0.01475523 -0.22923516  0.20152494 -0.15304424 -0.15312051  0.03262658]
#
# Para el ejemplo  211  es: [-0.13125305 -0.2360688   0.17701323 -0.18860736 -0.06599469 -0.09146963]
#
# Para el ejemplo  212  es: [ 0.38162997  0.01829846 -0.00232284 -0.01577267 -0.13926223  0.00042244]
#
# Para el ejemplo  213  es: [ 0.06716466 -0.07371222  0.03919129 -0.00755286 -0.0028191  -0.09969767]
#
# Para el ejemplo  214  es: [ 0.17364017 -0.02366548  0.13191064 -0.06312261 -0.02803517 -0.05074791]
#
# Para el ejemplo  215  es: [ 0.09831408  0.09482892  0.10890571  0.01202871  0.14730973 -0.17367182]
#
# Para el ejemplo  216  es: [ 0.07301961 -0.10944155  0.08232969 -0.04325877 -0.16333129  0.00490135]
#
# Para el ejemplo  217  es: [ 0.11669268 -0.29564659  0.1118657  -0.36941368 -0.13608393 -0.28621055]
#
# Para el ejemplo  218  es: [ 0.23423088 -0.14697044  0.03885624 -0.1705486  -0.16815899 -0.1523811 ]
#
# Para el ejemplo  219  es: [-0.04999536 -0.22416335  0.03932085  0.05074201 -0.04050853 -0.05857055]
#
# Para el ejemplo  220  es: [ 0.00560329  0.01314204  0.17832314 -0.09374551 -0.02887574 -0.03952344]
#
# Para el ejemplo  221  es: [ 0.30663503 -0.15546785 -0.06948009 -0.08950664 -0.05156119 -0.22509393]
#
# Para el ejemplo  222  es: [-0.06185761  0.08402873  0.20146242  0.01481275 -0.06127234  0.1392283 ]
#
# Para el ejemplo  223  es: [-0.06770047 -0.41343848  0.09633512 -0.16574387 -0.04714803 -0.1736037 ]
#
# Para el ejemplo  224  es: [ 0.26008637 -0.01255806  0.00606181  0.05988201 -0.08641846  0.06702874]
#
# Para el ejemplo  225  es: [-0.0235755  -0.24266269  0.13573641 -0.20134086 -0.17783446 -0.08967913]
#
# Para el ejemplo  226  es: [ 0.31361947  0.17914732 -0.02689419  0.04966841 -0.11071052  0.09027318]
#
# Para el ejemplo  227  es: [-0.01548509 -0.07638276  0.09511919 -0.02490713 -0.15240206  0.09439345]
#
# Para el ejemplo  228  es: [ 0.10700731 -0.21691112  0.07736342 -0.14319648 -0.04474399 -0.18378923]
#
# Para el ejemplo  229  es: [ 0.1754836  -0.29303453  0.08083771 -0.30492282 -0.23967198 -0.12076756]
#
# Para el ejemplo  230  es: [ 0.02371141 -0.31643527  0.16905986 -0.28106075 -0.16165597 -0.05315736]
#
# Para el ejemplo  231  es: [-0.07744884 -0.07510456  0.1614884   0.02633865 -0.11478055  0.11734296]
#
# Para el ejemplo  232  es: [ 0.05411314 -0.24515379  0.07242032 -0.1564214  -0.0379453  -0.23752824]
#
# Para el ejemplo  233  es: [-0.08114839 -0.2477387   0.11377339 -0.0793778  -0.18902688  0.07619522]
#
# Para el ejemplo  234  es: [-0.04162723 -0.34725907  0.08226125 -0.32057512 -0.19805878 -0.2607844 ]
#
# Para el ejemplo  235  es: [ 0.05320657 -0.11076776  0.01684997 -0.06246178 -0.06800073 -0.13184964]
#
# Para el ejemplo  236  es: [ 0.04906287 -0.15426808  0.12126632 -0.1355522  -0.03888324 -0.1447593 ]
#
# Para el ejemplo  237  es: [ 0.0316043  -0.04404477  0.09105299 -0.02303737  0.01681317 -0.09716809]
#
# Para el ejemplo  238  es: [ 0.19768117 -0.2807819   0.10358499 -0.31543045 -0.13051496 -0.22123602]
#
# Para el ejemplo  239  es: [ 0.22419658 -0.00707612  0.1625275  -0.1512338  -0.12932688 -0.01982593]
#
# Para el ejemplo  240  es: [ 0.15505737 -0.05840772  0.06495037 -0.0641892   0.05487993 -0.20732173]
#
# Para el ejemplo  241  es: [-0.21770616 -0.08779134  0.23396815 -0.05563718 -0.01185039  0.03624421]
#
# Para el ejemplo  242  es: [0.15929199 0.19705372 0.04571915 0.19154007 0.00079788 0.12483665]
#
# Para el ejemplo  243  es: [ 0.05543482 -0.00017226  0.10632658  0.00121025 -0.0426157   0.03360828]
#
# Para el ejemplo  244  es: [-0.07161132  0.05625552  0.18125393  0.10066544 -0.00306506  0.10523086]
#
# Para el ejemplo  245  es: [0.12046103 0.35735935 0.24146634 0.0210927  0.13005962 0.01846683]
#
# Para el ejemplo  246  es: [ 0.00263113 -0.15468458  0.02601895 -0.007284   -0.17019531  0.0673489 ]
#
# Para el ejemplo  247  es: [ 0.14250157 -0.21552148  0.00166753 -0.10883928 -0.05658378 -0.27983539]
#
# Para el ejemplo  248  es: [-0.00597703 -0.00425672  0.04367566  0.11392609  0.09974416 -0.07517779]
#
# Para el ejemplo  249  es: [-0.13147715 -0.11706227  0.17192639  0.11754773  0.01714403  0.06282962]
#
# Para el ejemplo  250  es: [ 0.24819649  0.00347984 -0.01986622  0.00280758 -0.0576792  -0.0249728 ]
#
# Para el ejemplo  251  es: [ 0.1254517  -0.19319241  0.05636985 -0.14273489 -0.1503525  -0.07112593]
#
# Para el ejemplo  252  es: [ 0.13774052  0.01195996  0.14373807 -0.09374711 -0.07869347  0.03844624]
#
# Para el ejemplo  253  es: [-0.08565307  0.01519586  0.12173434  0.00996773  0.09232372 -0.16948207]
#
# Para el ejemplo  254  es: [ 0.02882469 -0.01417251  0.12085474 -0.06918172  0.17833502 -0.32614917]
#
# Para el ejemplo  255  es: [ 0.00764207 -0.19360085  0.172705   -0.03676904 -0.17709548  0.21120393]
#
# Para el ejemplo  256  es: [-0.04181    -0.14137262  0.10157863 -0.12084669  0.00493297 -0.17239414]
#
# Para el ejemplo  257  es: [ 0.08092715 -0.02968014  0.07412292 -0.11467606 -0.14528028 -0.07406021]
#
# Para el ejemplo  258  es: [ 0.21727423  0.17037422  0.15403865 -0.18336218 -0.04259274 -0.13997339]
#
# Para el ejemplo  259  es: [ 0.18025174 -0.20053185  0.03386274 -0.2445028  -0.17784513 -0.2242487 ]
#
# Para el ejemplo  260  es: [-0.00230126 -0.37053994  0.01555785 -0.17794397 -0.10666701 -0.2814628 ]
#
# Para el ejemplo  261  es: [ 0.19555037  0.06340895  0.12211222 -0.0728153  -0.11210662  0.0060463 ]
#
# Para el ejemplo  262  es: [ 0.09672999  0.01679761 -0.04999954  0.14130931  0.08502187 -0.06478801]
#
# Para el ejemplo  263  es: [ 0.09238124 -0.20772764  0.08404257 -0.17195504 -0.13379473 -0.11308211]
#
# Para el ejemplo  264  es: [-0.13153613 -0.12482454  0.11651562 -0.03149104 -0.11929682  0.00892065]
#
# Para el ejemplo  265  es: [ 0.0845374  -0.16556483  0.16215806 -0.12313622 -0.05875683 -0.10900042]
#
# Para el ejemplo  266  es: [ 0.15418158  0.21527229  0.15619164 -0.00389605  0.01465515  0.0593287 ]
#
# Para el ejemplo  267  es: [ 0.03101549  0.0753571   0.07950804  0.08557493 -0.00896508  0.01956966]
#
# Para el ejemplo  268  es: [ 0.06137977 -0.14122227  0.05318665 -0.19868539  0.08209193 -0.33744039]
#
# Para el ejemplo  269  es: [-0.15736943 -0.30575613  0.17270698 -0.16545368 -0.0652618  -0.13883805]
#
# Para el ejemplo  270  es: [ 0.01126055 -0.10580113  0.17394762 -0.12479383 -0.09201941 -0.02063288]
#
# Para el ejemplo  271  es: [-0.00323174 -0.00517974  0.05822607 -0.10071842 -0.08979693 -0.17802117]
#
# Para el ejemplo  272  es: [ 0.12169242  0.09871322  0.06300802  0.00904473 -0.0986504   0.05788561]
#
# Para el ejemplo  273  es: [ 0.08454316 -0.14892117  0.11965318 -0.17603159 -0.06357678 -0.15422986]
#
# Para el ejemplo  274  es: [ 0.00964749 -0.178603    0.13278105 -0.09778272 -0.16278988  0.08609087]
#
# Para el ejemplo  275  es: [ 0.09699319  0.0600406   0.14155659  0.04182607 -0.02123634  0.10729465]
#
# Para el ejemplo  276  es: [ 0.04070748 -0.4443422   0.06125882 -0.33153658 -0.07228601 -0.40380739]
#
# Para el ejemplo  277  es: [-0.03686502 -0.20834703  0.15121033 -0.11727198 -0.01602034 -0.04840603]
#
# Para el ejemplo  278  es: [-0.00753116 -0.13959192  0.06928997 -0.08803225 -0.09212282 -0.0511542 ]
#
# Para el ejemplo  279  es: [ 0.04227162 -0.17785102  0.18754151 -0.1874038  -0.12846834  0.01255107]
#
# Para el ejemplo  280  es: [ 0.16859247  0.04470702  0.09578096 -0.15279096 -0.10817503 -0.1424737 ]
#
# Para el ejemplo  281  es: [ 0.42361082  0.13541362  0.00077579 -0.03344272 -0.04076783 -0.1463482 ]
#
# Para el ejemplo  282  es: [0.07386578 0.10362976 0.19192317 0.117918   0.12909306 0.06610093]
#
# Para el ejemplo  283  es: [ 0.14215807 -0.01593324  0.08035633 -0.0476168  -0.08083    -0.05435459]
#
# Para el ejemplo  284  es: [ 0.03256068 -0.04346483  0.15464726 -0.01579972 -0.07953965  0.07001895]
#
# Para el ejemplo  285  es: [ 0.03095301  0.02505506  0.18147099 -0.06631546  0.04844402 -0.07273037]
#
# Para el ejemplo  286  es: [ 0.13268537  0.08733475  0.02283365  0.02500269  0.05111859 -0.12388231]
#
# Para el ejemplo  287  es: [ 0.20111961 -0.13038981 -0.01323884 -0.12792733 -0.01039319 -0.30315622]
#
# Para el ejemplo  288  es: [ 0.04284766 -0.15891319  0.03094565 -0.22160008 -0.06915657 -0.31492331]
#
# Para el ejemplo  289  es: [-0.01406071  0.05508289  0.22948998 -0.17065611  0.02572547 -0.18187204]
#
# Para el ejemplo  290  es: [ 0.13619889 -0.10107241 -0.02818916 -0.07223313  0.01080798 -0.2421445 ]
#
# Para el ejemplo  291  es: [ 0.04219192 -0.11208959  0.15985131 -0.07774652 -0.12164947  0.03214014]
#
# Para el ejemplo  292  es: [ 0.1712906  -0.17597408  0.076278   -0.35291559 -0.10367809 -0.346001  ]
#
# Para el ejemplo  293  es: [ 0.14832109 -0.11107066  0.15708782 -0.20265274 -0.02599038 -0.21350443]
#
# Para el ejemplo  294  es: [ 0.17002905 -0.01838451  0.14523523 -0.14919008 -0.06450732 -0.07564402]
#
# Para el ejemplo  295  es: [ 0.31849    -0.01562973  0.08727423 -0.10595215 -0.03522425 -0.06197959]
#
# Para el ejemplo  296  es: [ 0.10096449  0.15239376  0.10597121  0.05964437  0.03533318 -0.00683692]
#
# Para el ejemplo  297  es: [ 0.01010292  0.05832614  0.2618093  -0.18450286 -0.10266181  0.00039871]
#
# Para el ejemplo  298  es: [ 0.04776719 -0.1110655   0.05497018 -0.04513988 -0.08666552 -0.03860317]
#
# Para el ejemplo  299  es: [0.03447449 0.2203759  0.20596507 0.00525318 0.03896672 0.02363431]
#
# Para el ejemplo  300  es: [-0.00870496 -0.2067015   0.18456089 -0.15522188  0.01424045 -0.18774623]
#
# Para el ejemplo  301  es: [ 0.04525427  0.11857167  0.0840201   0.06322671  0.16397278 -0.08420426]
#
# Para el ejemplo  302  es: [ 0.16256347 -0.00411282  0.0200973   0.00272102 -0.05724224 -0.12069776]
#
# Para el ejemplo  303  es: [ 0.16729624 -0.05513507  0.08294134 -0.14366499 -0.14863321 -0.01810234]
#
# Para el ejemplo  304  es: [ 0.09396951 -0.29125494  0.0147299  -0.17011691 -0.17037033 -0.27844285]
#
# Para el ejemplo  305  es: [ 0.14493502 -0.23776353  0.0938506  -0.03051093  0.07009027 -0.08347811]
#
# Para el ejemplo  306  es: [ 0.15139653 -0.21548094  0.02847954 -0.12140392 -0.21252582  0.02541339]
#
# Para el ejemplo  307  es: [-0.01777123 -0.19687912  0.06610717 -0.12376304 -0.10314743 -0.12951517]
#
# Para el ejemplo  308  es: [ 0.07561419 -0.16026605  0.10697871 -0.09378612 -0.13683949 -0.0092061 ]
#
# Para el ejemplo  309  es: [ 0.21349804 -0.13639535  0.00335288 -0.11876848 -0.16421512 -0.08836136]
#
# Para el ejemplo  310  es: [-0.01964436  0.05563096  0.18985933 -0.05080226 -0.10671812  0.13593487]
#
# Para el ejemplo  311  es: [ 0.13630876  0.06964444  0.21809515 -0.08566315 -0.16970503  0.18806548]
#
# Para el ejemplo  312  es: [ 0.06236394  0.02192088  0.1340176  -0.10639135 -0.06650668 -0.09459954]
#
# Para el ejemplo  313  es: [ 0.03640793 -0.15261658  0.17635435 -0.17847321 -0.04907752 -0.15539631]
#
# Para el ejemplo  314  es: [ 0.05609425  0.03393915  0.10321851 -0.11882635  0.1136099  -0.28259648]
#
# Para el ejemplo  315  es: [ 0.11515973 -0.14300325  0.12584334 -0.02942226 -0.04356214  0.01287448]
#
# Para el ejemplo  316  es: [ 0.05156965 -0.09263712  0.09400392  0.00330911 -0.02877079  0.03209941]
#
# Para el ejemplo  317  es: [ 0.03803056  0.07303706  0.20434462 -0.02338913  0.00147795 -0.00543128]
#
# Para el ejemplo  318  es: [ 0.19186266  0.23106472  0.03754071  0.05591428 -0.03664178  0.01035481]
#
# Para el ejemplo  319  es: [ 0.20411403 -0.06371742  0.00899936 -0.18517304 -0.07076156 -0.32827004]
#
# Para el ejemplo  320  es: [ 0.0333781  -0.16154715  0.17608953 -0.1360811  -0.10843968 -0.01917365]
#
# Para el ejemplo  321  es: [ 0.17850958 -0.20911966  0.08924357 -0.19054751 -0.13250826 -0.06638635]
#
# Para el ejemplo  322  es: [ 0.17550849  0.0969588   0.1716559  -0.03804569  0.00192976 -0.01328264]
#
# Para el ejemplo  323  es: [ 0.02499506 -0.21653806  0.07354874 -0.21594727 -0.07400633 -0.18900831]
#
# Para el ejemplo  324  es: [ 0.01894506 -0.14255856  0.13740479 -0.22830483 -0.15017158 -0.12948895]
#
# Para el ejemplo  325  es: [-0.06754123 -0.11464623  0.13492865 -0.10114485 -0.1253805  -0.01381562]
#
# Para el ejemplo  326  es: [ 0.06575037 -0.16711625  0.10896197 -0.14685243 -0.05926184 -0.21147227]
#
# Para el ejemplo  327  es: [-0.10010158 -0.14130549  0.03635985  0.03827724 -0.00322306 -0.07401266]
#
# Para el ejemplo  328  es: [ 0.22986706 -0.04188981  0.0144146  -0.03486835 -0.14034754  0.01077094]
#
# Para el ejemplo  329  es: [ 0.19871956 -0.08236644  0.04565655 -0.00270727 -0.05382473 -0.0648804 ]
#
# Para el ejemplo  330  es: [ 0.18742648 -0.22530042  0.04972048 -0.1781396  -0.22481409 -0.03792032]
#
# Para el ejemplo  331  es: [ 0.19393335  0.10079651  0.10274564 -0.03788128 -0.18847365  0.12610677]
#
# Para el ejemplo  332  es: [-0.04036969 -0.11107959  0.16513189 -0.04724338  0.00868979 -0.05375464]
#
# Para el ejemplo  333  es: [ 0.0295629   0.04884178  0.16675217 -0.04430475 -0.09243954  0.08480525]
#
# Para el ejemplo  334  es: [0.03460244 0.13313888 0.19621983 0.14993814 0.04749203 0.10764844]
#
# Para el ejemplo  335  es: [-0.08553899  0.20819559  0.22803803 -0.08796583  0.05721718 -0.10907883]
#
# Para el ejemplo  336  es: [ 0.15521545 -0.28034407 -0.02600234 -0.09216552 -0.14776246 -0.0970119 ]
#
# Para el ejemplo  337  es: [ 0.0931632  -0.16884246  0.07400251 -0.07651208 -0.00824556 -0.07403374]
#
# Para el ejemplo  338  es: [-0.05472757 -0.07742202  0.15136798 -0.0852466  -0.04203901  0.01242277]
#
# Para el ejemplo  339  es: [ 0.02472176 -0.01462778  0.12365306  0.04875315  0.05613845 -0.03893746]
#
# Para el ejemplo  340  es: [ 0.16747841  0.23821624  0.10731689 -0.06777723 -0.00100918 -0.171333  ]
#
# Para el ejemplo  341  es: [0.16097728 0.12508373 0.09310331 0.24856959 0.06341224 0.18758913]
#
# Para el ejemplo  342  es: [-0.06327947  0.26408809  0.16305319  0.26627234  0.24428918  0.08376831]
#
# Para el ejemplo  343  es: [-0.1004272  -0.16463642  0.20119317 -0.14837177 -0.11189917 -0.00081304]
#
# Para el ejemplo  344  es: [ 0.19140103 -0.14021896  0.01214581 -0.1042389  -0.09098604 -0.17863222]
#
# Para el ejemplo  345  es: [ 0.11821102 -0.08980653  0.07929406 -0.20874116 -0.09007242 -0.1801954 ]
#
# Para el ejemplo  346  es: [ 0.14147796  0.00038234  0.02124205 -0.21965772 -0.05844489 -0.24727974]
#
# Para el ejemplo  347  es: [ 0.01098022 -0.29380229  0.07103464 -0.13883024 -0.23394681  0.0044449 ]
#
# Para el ejemplo  348  es: [ 0.22228267 -0.14589518  0.05406238 -0.23791962 -0.18004063 -0.1451563 ]
#
# Para el ejemplo  349  es: [ 0.00085864 -0.03063689  0.04349604 -0.06147377 -0.06908139 -0.12787941]
#
# Para el ejemplo  350  es: [ 0.12596904  0.15800504  0.12831683 -0.06483972 -0.03500316 -0.0153074 ]
#
# Para el ejemplo  351  es: [ 0.09065255  0.15455142  0.13147641 -0.05377047 -0.03393965 -0.05280646]
#
# Para el ejemplo  352  es: [ 0.23504677  0.23306092 -0.06086914  0.21700091  0.02070085  0.04505625]
#
# Para el ejemplo  353  es: [ 0.1671721   0.04458162  0.0272825  -0.08462893 -0.00414041 -0.23255301]
#
# Para el ejemplo  354  es: [-0.02252919 -0.1417635  -0.02386456 -0.01332193 -0.10943569 -0.07877745]
#
# Para el ejemplo  355  es: [ 0.04381785 -0.16011156  0.15179099 -0.21418433 -0.26417927  0.03223435]
#
# Para el ejemplo  356  es: [ 0.08150778 -0.16667472  0.13357248 -0.31117431 -0.14831743 -0.17799099]
#
# Para el ejemplo  357  es: [ 0.25589351  0.0424588   0.00131845  0.0727038  -0.04758187 -0.00608388]
#
# Para el ejemplo  358  es: [ 0.14266543 -0.03198104  0.13609443  0.04890845 -0.04288481  0.15427557]
#
# Para el ejemplo  359  es: [ 0.05495161  0.05217716  0.09395104 -0.06474959 -0.02107905 -0.0300596 ]
#
# Para el ejemplo  360  es: [ 0.04184601 -0.15910605  0.14244859 -0.14495291 -0.06588884 -0.06261505]
#
# Para el ejemplo  361  es: [ 0.08297732  0.09925362  0.1349171   0.13695551 -0.01847107  0.22817726]
#
# Para el ejemplo  362  es: [ 0.11316419 -0.21907279  0.08646601 -0.19988705 -0.11876754 -0.15082561]
#
# Para el ejemplo  363  es: [ 0.04883584 -0.21565729  0.10655376 -0.2182526  -0.03182583 -0.29189668]
#
# Para el ejemplo  364  es: [ 0.13949739 -0.00388897 -0.0027708   0.04304138 -0.07998393  0.01928694]
#
# Para el ejemplo  365  es: [ 0.01846502 -0.16207786  0.1467305  -0.11806038 -0.18169115  0.10752869]
#
# Para el ejemplo  366  es: [ 0.21505571  0.04386378  0.09041621  0.01867578 -0.11893845  0.08515417]
#
# Para el ejemplo  367  es: [ 0.19878006  0.04024978  0.08831914 -0.10046229 -0.02943628 -0.14332527]
#
# Para el ejemplo  368  es: [ 0.01386719 -0.21758843  0.09077493 -0.1509671  -0.02888803 -0.21485242]
#
# Para el ejemplo  369  es: [ 0.32303652 -0.00712242 -0.04370505 -0.03186823 -0.00189231 -0.17844965]
#
# Para el ejemplo  370  es: [ 0.12012509 -0.32688943  0.07987388 -0.21422643 -0.20548603 -0.10070748]
#
# Para el ejemplo  371  es: [ 0.05336249  0.02684192  0.08896544 -0.10764392 -0.00715269 -0.17164116]
#
# Para el ejemplo  372  es: [ 0.11230972 -0.23899809  0.09977369 -0.23904053 -0.07816472 -0.22789298]
#
# Para el ejemplo  373  es: [ 0.15860706 -0.15735156  0.00998078 -0.00639316 -0.11461484  0.04854424]
#
# Para el ejemplo  374  es: [ 0.0400137   0.02591034  0.16477821 -0.08031487 -0.03057758 -0.04595483]
#
# Para el ejemplo  375  es: [ 0.20341127  0.0173121   0.08789904 -0.00517354 -0.0328428  -0.01708568]
#
# Para el ejemplo  376  es: [ 0.00811464 -0.33827812  0.03599943 -0.25712508 -0.1860558  -0.21170432]
#
# Para el ejemplo  377  es: [ 0.21556617 -0.02925634 -0.0180988  -0.02791429 -0.04278147 -0.14173097]
#
# Para el ejemplo  378  es: [ 0.07238919 -0.15422208  0.16153972 -0.20129537 -0.08894974 -0.10415445]
#
# Para el ejemplo  379  es: [ 0.03383021 -0.24423573  0.11053344 -0.28506296 -0.06414648 -0.32802024]
#
# Para el ejemplo  380  es: [0.1306552  0.01471395 0.04584988 0.19696437 0.00288661 0.1800705 ]
#
# Para el ejemplo  381  es: [ 0.12150776 -0.20364754  0.03258066 -0.14573591 -0.23483377  0.00300562]
#
# Para el ejemplo  382  es: [ 0.17584883 -0.1036475   0.09473324 -0.18369176 -0.00657001 -0.16937991]
#
# Para el ejemplo  383  es: [-0.06389076 -0.2218717   0.12718226 -0.19561364 -0.23283426  0.03717072]
#
# Para el ejemplo  384  es: [ 0.04894982  0.1416346   0.04475031 -0.02770172 -0.0738055   0.00184625]
#
# Para el ejemplo  385  es: [ 0.22423514  0.13481678  0.03122678 -0.18914175  0.03635764 -0.35178048]
#
# Para el ejemplo  386  es: [ 0.04986943 -0.34903837  0.12454996 -0.36565381 -0.11429896 -0.31075416]
#
# Para el ejemplo  387  es: [ 0.0830086  -0.05829845  0.09138446 -0.14935661 -0.0673222  -0.16359574]
#
# Para el ejemplo  388  es: [ 0.09331971 -0.18401369  0.0527547  -0.03508797 -0.05902748 -0.06861395]
#
# Para el ejemplo  389  es: [ 0.05943411  0.02185654 -0.00502459 -0.07459745 -0.10934214 -0.05923702]
#
# Para el ejemplo  390  es: [ 0.02778859  0.06325145  0.21962978 -0.23746231 -0.13740245 -0.01949339]
#
# Para el ejemplo  391  es: [-0.01726064 -0.08356802  0.16621152 -0.06479598 -0.05763197 -0.05620358]
#
# Para el ejemplo  392  es: [0.21540638 0.44371056 0.06486946 0.25521813 0.03378215 0.18836028]
#
# Para el ejemplo  393  es: [-0.07000283  0.07434429  0.25470549 -0.13255141 -0.13430579  0.10869245]
#
# Para el ejemplo  394  es: [ 0.09434229 -0.0469137   0.11903992 -0.16602576 -0.08078064 -0.1230563 ]
#
# Para el ejemplo  395  es: [ 0.11372331 -0.09205002  0.13870857 -0.2387622  -0.03682784 -0.17089956]
#
# Para el ejemplo  396  es: [ 0.10136823 -0.26314726 -0.01462487 -0.16294975 -0.06355322 -0.31351052]
#
# Para el ejemplo  397  es: [ 0.1300038  -0.07084207  0.12083618 -0.18311842 -0.09158601 -0.13801338]
#
# Para el ejemplo  398  es: [ 0.11427578 -0.15685263  0.03882501 -0.22889251 -0.17207041 -0.18123874]
#
# Para el ejemplo  399  es: [ 0.20155756  0.10528995  0.0494036  -0.0535531   0.08566822 -0.15633927]
#
# Para el ejemplo  400  es: [ 0.16099328 -0.14673776  0.11214856 -0.23869403 -0.04680329 -0.1922244 ]
#
# Para el ejemplo  401  es: [ 0.0738113   0.08092668  0.03850169  0.07604636  0.02648467 -0.09578796]
#
# Para el ejemplo  402  es: [ 0.0167821   0.04741577  0.14999486 -0.10967534  0.02687525 -0.11205106]
#
# Para el ejemplo  403  es: [ 0.1548962  -0.09561632  0.00563168 -0.19102221 -0.12700013 -0.23738666]
#
# Para el ejemplo  404  es: [ 0.17655439 -0.04630088  0.11968452 -0.27104527 -0.0054104  -0.29761237]
#
# Para el ejemplo  405  es: [ 0.15517567 -0.10985577 -0.03487753 -0.13418632 -0.10386355 -0.14525779]
#
# Para el ejemplo  406  es: [0.18567245 0.10533328 0.03034869 0.16671408 0.06371986 0.04659391]
#
# Para el ejemplo  407  es: [ 0.09951024 -0.12051572  0.09389844 -0.09773483 -0.03757204 -0.13211027]
#
# Para el ejemplo  408  es: [ 0.0562996  -0.20696432  0.09049392 -0.05499268 -0.03867199 -0.10531183]
#
# Para el ejemplo  409  es: [ 0.08306955 -0.24755653  0.00869014 -0.22047546 -0.22503721 -0.17739438]
#
# Para el ejemplo  410  es: [ 0.29738244  0.01449168  0.06708772 -0.16293699 -0.12367846 -0.14062521]
#
# Para el ejemplo  411  es: [-0.06206275 -0.03159205  0.22147743 -0.08589075 -0.02239827  0.0094386 ]
#
# Para el ejemplo  412  es: [ 0.14428144  0.09656633  0.11651408 -0.00398621 -0.01540969 -0.04226446]
#
# Para el ejemplo  413  es: [ 0.18815848 -0.17207821  0.18859857 -0.08450421 -0.07169685  0.0628486 ]
#
# Para el ejemplo  414  es: [ 0.00211129  0.03769801  0.10824797  0.00824201  0.0616075  -0.08857874]
#
# Para el ejemplo  415  es: [ 0.05210737 -0.08917574  0.23034908 -0.03620645 -0.07473664  0.17503088]
#
# Para el ejemplo  416  es: [-0.04989712 -0.18590322  0.20725356 -0.09208359 -0.10920255  0.10419699]
#
# Para el ejemplo  417  es: [ 0.11938843  0.01479519  0.00615104 -0.04656694  0.04343486 -0.26251436]
#
# Para el ejemplo  418  es: [ 0.10072319 -0.00688855  0.1351794  -0.03743584 -0.02859782 -0.01992209]
#
# Para el ejemplo  419  es: [ 0.14460978 -0.05420027  0.08925273 -0.15514157  0.01886077 -0.29440667]
#
# Para el ejemplo  420  es: [-0.0095914   0.1246649   0.15320308  0.06631659 -0.08305365  0.12035   ]
#
# Para el ejemplo  421  es: [ 0.0300026  -0.07261516  0.17285376 -0.01739998 -0.1281317   0.18025054]
#
# Para el ejemplo  422  es: [ 0.15142141 -0.09011667  0.152015   -0.16328063  0.01196858 -0.21974678]
#
# Para el ejemplo  423  es: [ 0.09023597  0.12645381  0.02690787 -0.04368031  0.09726275 -0.21755499]
#
# Para el ejemplo  424  es: [ 0.13897903 -0.06868671  0.15640108 -0.26610834 -0.05794174 -0.15119647]
#
# Para el ejemplo  425  es: [ 0.24893383 -0.12849148  0.06265527 -0.2404844  -0.05610406 -0.24323751]
#
# Para el ejemplo  426  es: [ 0.28940595 -0.04435418 -0.02842317 -0.10051508 -0.17683668 -0.02939737]
#
# Para el ejemplo  427  es: [ 1.12388502e-01 -6.42231129e-02  3.65481717e-02 -1.16209405e-01
#   1.78311892e-04 -2.31284747e-01]
#
# Para el ejemplo  428  es: [ 0.11591287 -0.21441388  0.12531827 -0.15869223 -0.10006702 -0.09715256]
#
# Para el ejemplo  429  es: [ 0.17097161 -0.27383812  0.23096636 -0.45628282 -0.17564625 -0.27517083]
#
# Para el ejemplo  430  es: [ 0.03378835  0.26654523  0.0851904   0.17049579  0.1877958  -0.03163259]
#
# Para el ejemplo  431  es: [-0.19192398 -0.20244265  0.207707   -0.21253708  0.05401646 -0.22227799]
#
# Para el ejemplo  432  es: [0.0863482  0.14733772 0.1321571  0.10573978 0.07064314 0.04989001]
#
# Para el ejemplo  433  es: [ 0.06054571 -0.06049812  0.13240094 -0.07549651  0.00305173 -0.09310153]
#
# Para el ejemplo  434  es: [ 0.20049036  0.14212813  0.06210254  0.01740323 -0.00104164  0.05136025]
#
# Para el ejemplo  435  es: [ 0.09870416 -0.02486399  0.14819734 -0.06767903  0.01084479 -0.03722241]
#
# Para el ejemplo  436  es: [ 0.16963262  0.12227757 -0.00897157  0.04057249  0.05929736 -0.10016368]
#
# Para el ejemplo  437  es: [ 0.00987205 -0.13701881  0.04217788 -0.11452857 -0.03921976 -0.21318364]
#
# Para el ejemplo  438  es: [ 0.24248457 -0.16956011  0.03123223 -0.31239465  0.07212861 -0.5133885 ]
#
# Para el ejemplo  439  es: [ 0.0508482   0.03469624 -0.00034521  0.08381327  0.04208232 -0.05142177]
#
# Para el ejemplo  440  es: [ 0.14433244 -0.05758054  0.12642652 -0.09261457 -0.16781598  0.10488339]
#
# Para el ejemplo  441  es: [ 0.05109259 -0.03389699  0.1624129  -0.26056783 -0.17570579 -0.11867156]
#
# Para el ejemplo  442  es: [ 0.17655872  0.00337488 -0.04015117  0.18958418  0.03102976  0.00629041]
#
# Para el ejemplo  443  es: [-0.10230472 -0.03426543  0.25298875 -0.03514806 -0.07356708  0.14365067]
#
# Para el ejemplo  444  es: [ 0.13157455 -0.09718758  0.05044432 -0.08838914  0.03472049 -0.25274177]
#
# Para el ejemplo  445  es: [-0.00972952  0.05625297  0.19631638 -0.07541325 -0.00529585 -0.05443242]
#
# Para el ejemplo  446  es: [-0.04819418 -0.18015744  0.09578949 -0.07346343  0.0364527  -0.13271298]
#
# Para el ejemplo  447  es: [ 0.08291737 -0.34164849  0.13377449 -0.23717834 -0.07914582 -0.25271778]
#
# Para el ejemplo  448  es: [-0.04137131 -0.03774577  0.08766704  0.00983789 -0.11654875  0.00245689]
#
# Para el ejemplo  449  es: [ 0.12616187 -0.11636222  0.06580828  0.04740654 -0.08463752  0.06338942]
#
# Para el ejemplo  450  es: [-0.12483065 -0.09972266  0.0622047   0.11892918  0.08207439 -0.07472859]
#
# Para el ejemplo  451  es: [ 0.19412443 -0.063907    0.06818915 -0.11546807 -0.01457211 -0.12864615]
#
# Para el ejemplo  452  es: [ 0.14033781 -0.08181495  0.01313718 -0.01836973  0.06436193 -0.19397506]
#
# Para el ejemplo  453  es: [ 0.26975967  0.00148629  0.0972498  -0.29050925 -0.09789271 -0.29981786]
#
# Para el ejemplo  454  es: [ 0.27025652  0.17799211  0.0235556   0.04609635 -0.10099567  0.0322256 ]
#
# Para el ejemplo  455  es: [ 0.08582488 -0.14588851  0.19646959 -0.08602843 -0.13117126  0.15666959]
#
# Para el ejemplo  456  es: [ 0.08260069 -0.05002618  0.16486172 -0.25675543 -0.1465855  -0.17368063]
#
# Para el ejemplo  457  es: [-0.01268838  0.07860126  0.10411464  0.02851598  0.00520153  0.02844024]
#
# Para el ejemplo  458  es: [ 0.18842617  0.08764716  0.01754578  0.03590986  0.06355452 -0.09984605]
#
# Para el ejemplo  459  es: [-0.00914048 -0.40929056  0.08804729 -0.21400334 -0.12239088 -0.17549218]
#
# Para el ejemplo  460  es: [-0.19563991 -0.20044353  0.23108834 -0.21600471 -0.02143192 -0.1323279 ]
#
# Para el ejemplo  461  es: [ 0.18951271 -0.14068239 -0.03149818 -0.06996685 -0.0883997  -0.13877761]
#
# Para el ejemplo  462  es: [-0.08260335  0.06005647  0.14118621  0.06398598  0.0821074  -0.01866532]
#
# Para el ejemplo  463  es: [0.17967398 0.07776914 0.10432987 0.08485618 0.03818392 0.07541158]
#
# Para el ejemplo  464  es: [ 0.11704257 -0.12408261  0.07014156 -0.18354265 -0.09487297 -0.16221106]
#
# Para el ejemplo  465  es: [ 6.67180426e-05 -9.02855179e-02  1.11461386e-01 -7.81992474e-02
#   1.39935595e-01 -3.05709440e-01]
#
# Para el ejemplo  466  es: [-0.12819986 -0.12082029  0.1784789  -0.04480391 -0.10561811  0.03224038]
#
# Para el ejemplo  467  es: [-0.07391131 -0.23209655  0.12200773 -0.19588058 -0.11856358 -0.0917857 ]
#
# Para el ejemplo  468  es: [ 0.14491925 -0.00439701  0.09204108 -0.06709634 -0.14195097  0.06607853]
#
# Para el ejemplo  469  es: [ 0.17324647  0.05075759  0.07359738 -0.16984086  0.04200026 -0.33159001]
#
# Para el ejemplo  470  es: [ 0.09387213 -0.1136465   0.16307456 -0.22092371 -0.14707862 -0.10976261]
#
# Para el ejemplo  471  es: [ 0.2561778  -0.08563058 -0.00406714 -0.05395277 -0.13136616 -0.00642204]
#
# Para el ejemplo  472  es: [ 0.03859578  0.12282463  0.18404804 -0.0438416  -0.06634423  0.05659084]
#
# Para el ejemplo  473  es: [ 0.20928468  0.14902118  0.01543289  0.09270748  0.10337188 -0.09081618]
#
# Para el ejemplo  474  es: [ 0.2380444   0.17449412  0.04211953  0.04743443  0.04857993 -0.12166639]
#
# Para el ejemplo  475  es: [ 0.04744222 -0.17390454  0.15824115 -0.14078089 -0.15356508  0.01900901]
#
# Para el ejemplo  476  es: [ 0.08144949 -0.18753042  0.1052017  -0.09985392 -0.17759289  0.05292076]
#
# ...
#
# Para el ejemplo  3845  es: [ 0.05002453  0.02314878  0.08106824 -0.06665503  0.02088545 -0.17720888]
#
# Para el ejemplo  3846  es: [-0.07176501 -0.1992081   0.13558157 -0.06326188  0.0390185  -0.1284098 ]
#
# Para el ejemplo  3847  es: [ 0.06803071 -0.19203394  0.0233965  -0.04700428 -0.05776038 -0.12087935]
#
# Para el ejemplo  3848  es: [ 0.00341644 -0.16281107  0.1037308  -0.02978225 -0.09927634  0.05833488]
#
# Para el ejemplo  3849  es: [ 0.08798322  0.06667717  0.1335812  -0.08087462 -0.04864464 -0.03485341]
#
# Para el ejemplo  3850  es: [ 0.24461114  0.03232793  0.04978056 -0.08719199 -0.03369621 -0.18058691]
#
# Para el ejemplo  3851  es: [-0.03001249 -0.21337796  0.14091365 -0.01103875 -0.05028861  0.00025493]
#
# Para el ejemplo  3852  es: [ 0.06047423 -0.06522271  0.03039413  0.05521875 -0.00066776 -0.09296002]
#
# Para el ejemplo  3853  es: [ 0.21848215 -0.10243624  0.0434012  -0.0342603  -0.07118798  0.00896643]
#
# Para el ejemplo  3854  es: [-0.0257516  -0.09576196  0.18208585 -0.07434791 -0.02204383  0.00352437]
#
# Para el ejemplo  3855  es: [ 0.17254526  0.20848209  0.10376121 -0.02549196 -0.01102283  0.00542831]
#
# Para el ejemplo  3856  es: [ 0.06477512 -0.00418991  0.06662977 -0.06704516 -0.0435243  -0.11321152]
#
# Para el ejemplo  3857  es: [ 1.37504632e-01  1.80289315e-02 -7.19622181e-02  1.40566203e-04
#   9.65919335e-02 -2.78475703e-01]
#
# Para el ejemplo  3858  es: [ 0.00737198 -0.17846795  0.09861643 -0.17022408  0.02236143 -0.27595581]
#
# Para el ejemplo  3859  es: [ 0.16111797  0.22025037  0.07134181  0.09501557  0.07558324 -0.04317349]
#
# Para el ejemplo  3860  es: [ 0.27320634 -0.07591632  0.02802633 -0.13189165 -0.02883987 -0.14536874]
#
# Para el ejemplo  3861  es: [ 0.25682349 -0.13505758 -0.08113129  0.01882643 -0.06888883 -0.14544611]
#
# Para el ejemplo  3862  es: [ 0.02261768 -0.21731033  0.09976646 -0.25971142 -0.02856229 -0.30386352]
#
# Para el ejemplo  3863  es: [ 0.07533734  0.19199931  0.13514031  0.07653438 -0.06164538  0.06621759]
#
# Para el ejemplo  3864  es: [ 0.25507365  0.07873303  0.03233134 -0.08136054 -0.1375079  -0.03437549]
#
# Para el ejemplo  3865  es: [-0.10022034 -0.18030616  0.19725387 -0.1322136  -0.11696911 -0.01833718]
#
# Para el ejemplo  3866  es: [ 0.09172373 -0.19284502  0.11867275 -0.11476514 -0.19222829  0.05599985]
#
# Para el ejemplo  3867  es: [-0.14199179 -0.07098996  0.1966116  -0.08726025 -0.05289306 -0.04022622]
#
# Para el ejemplo  3868  es: [-0.01842963 -0.10858981  0.18495534 -0.09727507 -0.14878014  0.05973253]
#
# Para el ejemplo  3869  es: [ 0.20216647  0.17726347  0.07375294  0.05487858  0.06509907 -0.0766403 ]
#
# Para el ejemplo  3870  es: [-0.09823006 -0.17717478  0.09748139 -0.15695816 -0.10719087 -0.15568149]
#
# Para el ejemplo  3871  es: [ 0.1715976   0.26862059  0.07957059  0.13797412  0.17316687 -0.09082605]
#
# Para el ejemplo  3872  es: [ 0.17728088  0.17306236  0.12003281  0.07136149 -0.02936543  0.11551214]
#
# Para el ejemplo  3873  es: [-0.02744036 -0.02370376  0.06611477  0.09130981 -0.05636851  0.08642275]
#
# Para el ejemplo  3874  es: [-0.01608128 -0.25596275  0.20552816 -0.14947396 -0.28708868  0.26549509]
#
# Para el ejemplo  3875  es: [ 0.06751624 -0.01744185  0.12570074  0.0069125  -0.09852111  0.13522296]
#
# Para el ejemplo  3876  es: [ 0.19677196  0.03116048  0.07185928 -0.10605492 -0.03386446 -0.07039096]
#
# Para el ejemplo  3877  es: [ 0.27946171 -0.09556762  0.01301936 -0.10556457 -0.11825813 -0.04506089]
#
# Para el ejemplo  3878  es: [-0.03783745 -0.25189901  0.13698087 -0.10717164 -0.16010565  0.00757759]
#
# Para el ejemplo  3879  es: [ 0.06188378 -0.08917126  0.08186668 -0.07063176 -0.11912079 -0.02357118]
#
# Para el ejemplo  3880  es: [-0.02500313  0.04438969  0.17606224 -0.02076226 -0.04689715  0.06180014]
#
# Para el ejemplo  3881  es: [ 0.19768598  0.1089646   0.04827391 -0.14165114 -0.02899204 -0.23234042]
#
# Para el ejemplo  3882  es: [ 0.00317377 -0.28416731  0.04710292 -0.20209119 -0.17294816 -0.14160501]
#
# Para el ejemplo  3883  es: [ 0.05420105 -0.27263178  0.05298329 -0.16741247 -0.27011299 -0.05167272]
#
# Para el ejemplo  3884  es: [ 0.08722765 -0.13972096  0.19495189 -0.18467188 -0.19874661  0.05376385]
#
# Para el ejemplo  3885  es: [ 0.22019081 -0.09315027 -0.01011856 -0.09248221 -0.08772447 -0.17259778]
#
# Para el ejemplo  3886  es: [ 0.15658602 -0.18633139  0.06728632 -0.22782656 -0.15716331 -0.10781106]
#
# Para el ejemplo  3887  es: [ 0.01818909  0.0345734   0.16348373 -0.10894666 -0.07139337 -0.00877417]
#
# Para el ejemplo  3888  es: [-0.0525447  -0.11853585  0.11005381 -0.09251292 -0.01491615 -0.09757077]
#
# Para el ejemplo  3889  es: [ 0.18383296  0.13070502  0.15698009 -0.00698139  0.05927565 -0.0447206 ]
#
# Para el ejemplo  3890  es: [ 0.01825426 -0.42417397  0.08307407 -0.24788198 -0.19640565 -0.13196548]
#
# Para el ejemplo  3891  es: [ 0.00660897 -0.15246235  0.2143122  -0.18437799 -0.04499677 -0.05420954]
#
# Para el ejemplo  3892  es: [ 0.24294786  0.11004995  0.03220833  0.11915991  0.10417035 -0.03026804]
#
# Para el ejemplo  3893  es: [ 0.08697522  0.02709887 -0.02512065 -0.05258785 -0.01251128 -0.18993154]
#
# Para el ejemplo  3894  es: [ 0.23665613 -0.09327681  0.03767618 -0.17854862 -0.05479947 -0.22819518]
#
# Para el ejemplo  3895  es: [ 0.06911916 -0.19154991  0.01213219 -0.13481452 -0.06584244 -0.30338528]
#
# Para el ejemplo  3896  es: [ 0.04052113 -0.11776788  0.07862934 -0.08088104 -0.06776501 -0.11011936]
#
# Para el ejemplo  3897  es: [ 0.07656762 -0.15505485  0.16224628 -0.29920699 -0.14293112 -0.19008172]
#
# Para el ejemplo  3898  es: [ 0.29702264  0.20726969 -0.10764332  0.07810688  0.10688839 -0.24654247]
#
# Para el ejemplo  3899  es: [ 0.10545343 -0.12005304  0.10249602 -0.07553936  0.10146961 -0.18216112]
#
# Para el ejemplo  3900  es: [0.03147178 0.15842311 0.16290797 0.00801553 0.02887826 0.05977802]
#
# Para el ejemplo  3901  es: [-0.04713608 -0.08855698  0.17872114 -0.25074082 -0.04303499 -0.19450475]
#
# Para el ejemplo  3902  es: [ 0.07902888 -0.29813028  0.15237748 -0.14181005 -0.21823623  0.10556385]
#
# Para el ejemplo  3903  es: [ 0.20804223  0.09530405  0.10638868 -0.0618828   0.02862051 -0.11028614]
#
# Para el ejemplo  3904  es: [ 0.11662273 -0.06576606 -0.01455736 -0.16356668 -0.01406733 -0.29275314]
#
# Para el ejemplo  3905  es: [ 0.15252189 -0.03646873  0.15873986 -0.22137232 -0.03495617 -0.15592472]
#
# Para el ejemplo  3906  es: [ 0.16651648  0.13512695  0.04202704  0.11408333 -0.08291363  0.15857832]
#
# Para el ejemplo  3907  es: [ 0.02926668 -0.08127767  0.17416447 -0.233092   -0.15972216 -0.0747    ]
#
# Para el ejemplo  3908  es: [ 0.10119705 -0.12507602  0.09995929 -0.14631659 -0.10969433 -0.11204293]
#
# Para el ejemplo  3909  es: [ 0.17037546 -0.15504785 -0.00672804 -0.03785695 -0.11263054 -0.11788447]
#
# Para el ejemplo  3910  es: [-0.08734691 -0.01050306  0.08755445  0.06118435  0.00278941 -0.01457832]
#
# Para el ejemplo  3911  es: [ 0.06576066  0.09847932  0.10155103 -0.07730636 -0.07467314 -0.0449471 ]
#
# Para el ejemplo  3912  es: [-0.14603852 -0.26193822  0.16671618 -0.09561736 -0.06478357 -0.06732248]
#
# Para el ejemplo  3913  es: [ 0.30819501  0.05274448 -0.06990252  0.14458192 -0.06894827  0.03974893]
#
# Para el ejemplo  3914  es: [ 0.09698062 -0.32933714  0.13819516 -0.24132577 -0.19194196 -0.11125503]
#
# Para el ejemplo  3915  es: [-0.04505428 -0.09560671  0.21553029 -0.02483435 -0.09450185  0.12389137]
#
# Para el ejemplo  3916  es: [ 0.28110126  0.04956801 -0.05465872  0.02308122 -0.07383991 -0.01311668]
#
# Para el ejemplo  3917  es: [ 0.06588965  0.09181508  0.05741676  0.12575806 -0.06121771  0.16759138]
#
# Para el ejemplo  3918  es: [0.0240874  0.05059682 0.00693631 0.16758514 0.08364779 0.00250773]
#
# Para el ejemplo  3919  es: [ 0.08883072 -0.07097202  0.26062829 -0.04202341 -0.19332745  0.22335588]
#
# Para el ejemplo  3920  es: [ 0.08333826 -0.07905711  0.03856751 -0.00060066  0.06926265 -0.16554246]
#
# Para el ejemplo  3921  es: [ 0.15127247 -0.00697199  0.14442347 -0.16009847 -0.03973353 -0.13564044]
#
# Para el ejemplo  3922  es: [ 0.07119044 -0.13167039  0.10850559 -0.23342657 -0.03581844 -0.30974147]
#
# Para el ejemplo  3923  es: [ 0.20548717  0.1144253   0.11264404  0.08605181 -0.03032692  0.13959454]
#
# Para el ejemplo  3924  es: [ 0.15895424 -0.0989664   0.02017868  0.09382035  0.06240636 -0.05755135]
#
# Para el ejemplo  3925  es: [ 0.10941458 -0.12846841  0.07498412 -0.07290929  0.03258258 -0.1792208 ]
#
# Para el ejemplo  3926  es: [ 0.27507255  0.10328844  0.01340807 -0.09301797 -0.17521773 -0.09999951]
#
# Para el ejemplo  3927  es: [ 0.1368607   0.06136813  0.06930215  0.00327397 -0.03579166 -0.00159259]
#
# Para el ejemplo  3928  es: [ 0.07730935 -0.05128175  0.127684   -0.10046232  0.01403128 -0.11390183]
#
# Para el ejemplo  3929  es: [ 0.14879152 -0.02688871  0.07666526 -0.02332741 -0.14716711  0.05923656]
#
# Para el ejemplo  3930  es: [ 0.15004897 -0.28690295 -0.01900467 -0.10079592 -0.07399534 -0.16348193]
#
# Para el ejemplo  3931  es: [-0.01757562  0.09050777  0.15703897  0.12784142  0.07441851  0.15409845]
#
# Para el ejemplo  3932  es: [ 0.09728893 -0.15116693  0.07384712 -0.1032978  -0.11379524 -0.11433172]
#
# Para el ejemplo  3933  es: [0.20028673 0.19573452 0.06159316 0.20961537 0.01476175 0.13970739]
#
# Para el ejemplo  3934  es: [ 0.23034065 -0.13379811  0.0693111  -0.06472021 -0.0543387  -0.06871481]
#
# Para el ejemplo  3935  es: [-0.16563887 -0.12141617  0.22143676 -0.17118265  0.02179089 -0.17390771]
#
# Para el ejemplo  3936  es: [-0.05047177 -0.12789812  0.18766067 -0.023439    0.07699492 -0.08014477]
#
# Para el ejemplo  3937  es: [-0.06383088  0.13240262  0.24202672  0.03941833  0.08669464  0.03821973]
#
# Para el ejemplo  3938  es: [ 0.13689006  0.12199021  0.12409957  0.00986593  0.07972    -0.09686787]
#
# Para el ejemplo  3939  es: [ 0.13143041 -0.02926493  0.08195518 -0.02203873 -0.16837806  0.04694982]
#
# Para el ejemplo  3940  es: [-0.12130802 -0.25469303  0.08860086 -0.23133216 -0.14280512 -0.23889675]
#
# Para el ejemplo  3941  es: [ 0.09150114 -0.17047417  0.09964562 -0.25040974 -0.01438449 -0.33027737]
#
# Para el ejemplo  3942  es: [ 0.21272739 -0.07558502  0.08459078 -0.07322867 -0.05704268 -0.05723193]
#
# Para el ejemplo  3943  es: [-0.10242667 -0.18437916  0.23162589 -0.33272559 -0.11566802 -0.19882605]
#
# Para el ejemplo  3944  es: [ 0.17936508  0.12417124  0.04265758 -0.11610243  0.02977438 -0.29148991]
#
# Para el ejemplo  3945  es: [0.25969642 0.14551408 0.11113255 0.07195275 0.03399289 0.08359304]
#
# Para el ejemplo  3946  es: [ 0.06870961  0.07573304  0.04614698  0.03609414 -0.02358147 -0.02481014]
#
# Para el ejemplo  3947  es: [-0.12421391 -0.21938644  0.06689591 -0.14722321 -0.09328998 -0.20998857]
#
# Para el ejemplo  3948  es: [-0.03426553 -0.20269763  0.16390335 -0.23317429 -0.0256409  -0.2017143 ]
#
# Para el ejemplo  3949  es: [-0.02593755 -0.19320383  0.09936138 -0.01051091 -0.15729769  0.0977107 ]
#
# Para el ejemplo  3950  es: [ 0.1064746  -0.26822393  0.07891643 -0.13109829 -0.04107082 -0.20999403]
#
# Para el ejemplo  3951  es: [ 0.26469149  0.08312491 -0.06400104 -0.09869337 -0.04681872 -0.28963092]
#
# Para el ejemplo  3952  es: [0.19987985 0.24174111 0.00590871 0.26019246 0.083849   0.14575787]
#
# Para el ejemplo  3953  es: [ 0.093315   -0.20480305  0.04031241 -0.07439331 -0.08775478 -0.10245723]
#
# Para el ejemplo  3954  es: [ 0.01387792 -0.10517228  0.09454152 -0.00334764  0.01954478 -0.09205577]
#
# Para el ejemplo  3955  es: [ 0.16567728 -0.0628279  -0.01141798  0.06041077 -0.01109885 -0.10954694]
#
# Para el ejemplo  3956  es: [0.11780781 0.25892516 0.14346525 0.0937754  0.04973595 0.16061051]
#
# Para el ejemplo  3957  es: [ 0.01978534 -0.09902355  0.10094109 -0.12568423  0.02289331 -0.20225684]
#
# Para el ejemplo  3958  es: [ 0.05321166 -0.19292318  0.11151904 -0.13912043 -0.08811723 -0.12705392]
#
# Para el ejemplo  3959  es: [ 0.12919165 -0.07283785  0.07620696 -0.1319188  -0.08005897 -0.13390127]
#
# Para el ejemplo  3960  es: [ 0.05967879 -0.14858189  0.04691835 -0.08288634 -0.15520717 -0.0305769 ]
#
# Para el ejemplo  3961  es: [ 0.17502205  0.06980994  0.10292752 -0.13258803 -0.03530933 -0.13596595]
#
# Para el ejemplo  3962  es: [ 0.03132708 -0.19006783  0.16784448 -0.16897965 -0.0720875  -0.04870404]
#
# Para el ejemplo  3963  es: [ 0.22333166  0.02636567  0.00743408 -0.00518804 -0.04107831 -0.10133785]
#
# Para el ejemplo  3964  es: [ 0.23580502  0.24896419  0.05387855 -0.0422573  -0.09810863 -0.05336267]
#
# Para el ejemplo  3965  es: [ 0.0709215  -0.20818635  0.03862478 -0.13581136 -0.09935424 -0.17729087]
#
# Para el ejemplo  3966  es: [ 0.1537688  -0.08014192  0.04702631  0.00354033  0.00105372 -0.06369902]
#
# Para el ejemplo  3967  es: [ 0.06009348  0.13716045  0.05549799  0.09436483  0.21441572 -0.07907922]
#
# Para el ejemplo  3968  es: [ 0.09105938 -0.06330788  0.11004456 -0.19892719 -0.18383307 -0.0821911 ]
#
# Para el ejemplo  3969  es: [ 0.39230013 -0.03896156 -0.05549551 -0.03728864  0.00557563 -0.19322013]
#
# Para el ejemplo  3970  es: [ 0.02946005 -0.10350283  0.12652276 -0.13770983 -0.12244125 -0.04577801]
#
# Para el ejemplo  3971  es: [ 0.18012703 -0.12828228  0.03105849 -0.1001274  -0.01560392 -0.21308256]
#
# Para el ejemplo  3972  es: [ 0.14170926 -0.00992394  0.16196894 -0.14321627 -0.19037099  0.01008877]
#
# Para el ejemplo  3973  es: [ 0.12422565  0.16581584 -0.00020211  0.09267077  0.05111118  0.00041725]
#
# Para el ejemplo  3974  es: [ 0.20571191 -0.20511353  0.04876169 -0.169983   -0.14866856  0.01148493]
#
# Para el ejemplo  3975  es: [ 0.08696279 -0.13854611  0.08324481 -0.19228946  0.06268872 -0.27693434]
#
# Para el ejemplo  3976  es: [ 0.22452711 -0.02229397 -0.03091449 -0.16131985 -0.06306359 -0.34564577]
#
# Para el ejemplo  3977  es: [ 0.2088769   0.19878724  0.13981463 -0.0019382  -0.07039889  0.10585734]
#
# Para el ejemplo  3978  es: [ 0.12483419 -0.23346602  0.04169059 -0.23033912 -0.20723869 -0.16341933]
#
# Para el ejemplo  3979  es: [ 0.20434684  0.07860921  0.17753127 -0.21725989 -0.03294191 -0.19902347]
#
# Para el ejemplo  3980  es: [ 0.08371046  0.03003769  0.12844426  0.10385221  0.09015214 -0.0059726 ]
#
# Para el ejemplo  3981  es: [ 0.02599212 -0.06804192  0.1512984  -0.10416296 -0.06041088 -0.05863062]
#
# Para el ejemplo  3982  es: [-0.02148931  0.04624766  0.17913188 -0.09651413  0.03573519 -0.07873086]
#
# Para el ejemplo  3983  es: [-0.07754457 -0.00956403  0.28470932 -0.28674877 -0.0996609  -0.04301808]
#
# Para el ejemplo  3984  es: [ 0.08165129 -0.17311984  0.15092541 -0.13454312 -0.14461423 -0.04142225]
#
# Para el ejemplo  3985  es: [ 0.0208949  -0.17685983 -0.01463102 -0.0982244  -0.14335974 -0.1005656 ]
#
# Para el ejemplo  3986  es: [0.1532728  0.13680517 0.05690563 0.18215687 0.1069929  0.06046453]
#
# Para el ejemplo  3987  es: [ 0.02448408 -0.11844839  0.1306374   0.03078599 -0.06879978  0.1284973 ]
#
# Para el ejemplo  3988  es: [ 0.15451443  0.05910307  0.02569117 -0.0151974   0.04387985 -0.12163003]
#
# Para el ejemplo  3989  es: [ 0.00983033 -0.26145776  0.14349087 -0.00532999 -0.12717247  0.15599826]
#
# Para el ejemplo  3990  es: [ 0.05998682 -0.25738891  0.03288496 -0.03206991 -0.20104753  0.04366291]
#
# Para el ejemplo  3991  es: [-0.01835258 -0.08373948  0.15943987 -0.08073214  0.01229494 -0.03063494]
#
# Para el ejemplo  3992  es: [ 0.05496389 -0.13291966  0.07192755 -0.05215998 -0.07333221 -0.04346991]
#
# Para el ejemplo  3993  es: [ 0.16517122 -0.1062218  -0.06342225 -0.08932711 -0.10239855 -0.19072323]
#
# Para el ejemplo  3994  es: [ 0.08115484 -0.04907467  0.10325284  0.0098017  -0.10750831  0.04624349]
#
# Para el ejemplo  3995  es: [ 0.22841307  0.04366251  0.01359755 -0.08820283 -0.06637047 -0.15033448]
#
# Para el ejemplo  3996  es: [-0.09686592 -0.0551744   0.22059962 -0.17790862  0.02040888 -0.0949942 ]
#
# Para el ejemplo  3997  es: [ 0.0231337   0.12060174  0.04878562  0.08811534 -0.01125948  0.03000771]
#
# Para el ejemplo  3998  es: [-0.01278439  0.02051634  0.16090962 -0.24288734  0.06907987 -0.36196121]
#
# Para el ejemplo  3999  es: [ 3.10852247e-01  1.85828831e-01  6.55225972e-05 -2.51781622e-02
#  -4.15702519e-02 -1.05379864e-01]
#
# Para el ejemplo  4000  es: [ 0.2015087   0.04470498  0.07327915 -0.07683321 -0.10939824  0.06292188]

# %% [markdown]
# ## Validaciones

# %%
#Para hacer las validaciones correspondientes, primero se crea la funcion del **Mean squeared error**

#haciendo calculo del error cuadratico medio:
def mean_squared_error(y_pred, y_actual):
    resta = y_pred - y_actual
    err_cuadrado = np.sum(resta ** 2)
    return err_cuadrado / len(y_pred)

# %%
# realiza la normalización de los datos de prueba
X_test = (X_test - mu)/ sigma


#Predicción Usando la Red Neuronal
pred = predict(Theta1, Theta2, X_test)

print(pred)
# Out:
# [[ 3.52896895e-02 -2.26796409e-02  8.60604711e-02 -1.75076532e-01
#   -3.45273869e-02 -2.42438242e-01]
#  [ 9.73896563e-02 -1.05257358e-01  1.14742027e-01 -8.58601600e-02
#   -1.49630279e-02 -3.88545840e-02]
#  [ 1.65600129e-01  4.97446759e-02  4.67929859e-02 -1.02712298e-02
#    1.12035483e-02 -9.15599061e-02]
#  ...
#  [-1.27843890e-02  2.05163399e-02  1.60909619e-01 -2.42887345e-01
#    6.90798654e-02 -3.61961209e-01]
#  [ 3.10852247e-01  1.85828831e-01  6.55225972e-05 -2.51781622e-02
#   -4.15702519e-02 -1.05379864e-01]
#  [ 2.01508702e-01  4.47049844e-02  7.32791509e-02 -7.68332127e-02
#   -1.09398242e-01  6.29218760e-02]]

# %%
X_test = (X_test - mu)/ sigma

pred = predict(Theta1, Theta2, X_test)
print(pred)

for i in range(30):
    print(f"Prediccion: {pred[i]}, Real: {y_test[i]}")
# Out:
# [[-0.07351792 -0.2964191   0.11629044 -0.1474606  -0.03649952 -0.15906408]
#  [ 0.04189288 -0.05420779  0.16318136 -0.11713597 -0.03210435 -0.04999235]
#  [ 0.18749062  0.02406559 -0.00382427 -0.03322095 -0.10039906 -0.09590622]
#  ...
#  [ 0.14093488  0.10219788  0.15873666  0.02861523  0.01002724  0.10376495]
#  [ 0.10863619 -0.09303553  0.08803491 -0.01537836 -0.0676472   0.05234217]
#  [ 0.14632763  0.11167262  0.10416723 -0.0058424   0.0269725  -0.08545197]]
# Prediccion: [-0.07351792 -0.2964191   0.11629044 -0.1474606  -0.03649952 -0.15906408], Real: 3
# Prediccion: [ 0.04189288 -0.05420779  0.16318136 -0.11713597 -0.03210435 -0.04999235], Real: 4
# Prediccion: [ 0.18749062  0.02406559 -0.00382427 -0.03322095 -0.10039906 -0.09590622], Real: 5
# Prediccion: [ 0.01627966 -0.11246521  0.18092375 -0.20888448 -0.09040369 -0.02915923], Real: 2
# Prediccion: [ 0.10050886  0.06300081  0.05181026 -0.02124505 -0.02043152 -0.11167105], Real: 2
# Prediccion: [ 0.15412679 -0.00423754  0.01387884 -0.04597204  0.05248167 -0.19819901], Real: 0
# Prediccion: [0.09406333 0.1954117  0.15363934 0.16211114 0.07013312 0.12579692], Real: 2
# Prediccion: [ 0.06270099 -0.18124471  0.14259117 -0.19690438 -0.06409876 -0.11429306], Real: 5
# Prediccion: [ 0.08100389 -0.03035731  0.05807994 -0.01507165 -0.05142811 -0.08737492], Real: 2
# Prediccion: [-0.0327878  -0.05764902  0.18023367 -0.13507253 -0.11503218 -0.05024802], Real: 3
# Prediccion: [ 0.15505003 -0.1109284   0.12585822 -0.19070626 -0.08866894 -0.11199932], Real: 1
# Prediccion: [ 0.24754148  0.15131132  0.17110437 -0.1141365  -0.10565225  0.0087528 ], Real: 0
# Prediccion: [ 0.10468598 -0.22220314  0.13167869 -0.15499909 -0.07981726 -0.18158719], Real: 4
# Prediccion: [ 0.0016129  -0.31055792  0.14978841 -0.25683179 -0.05416865 -0.2362312 ], Real: 4
# Prediccion: [ 0.10053844 -0.1554825   0.05059182 -0.06147115 -0.08186532 -0.09700492], Real: 5
# Prediccion: [-0.07387433 -0.18450357  0.25935828 -0.23948307 -0.13644107  0.00873398], Real: 0
# Prediccion: [ 0.1461344  -0.26004793  0.0408116  -0.18055756 -0.18137815 -0.066783  ], Real: 4
# Prediccion: [ 0.14634295 -0.05679767 -0.01847308  0.14347647  0.0351688  -0.0375241 ], Real: 5
# Prediccion: [ 0.20246653 -0.08565851  0.084353   -0.07246258 -0.07901694  0.0068289 ], Real: 0
# Prediccion: [-0.06061053 -0.17757354  0.08218941 -0.15501064 -0.25191306 -0.02326366], Real: 1
# Prediccion: [ 0.25069931 -0.08318889  0.00387809 -0.08296876 -0.01488242 -0.23255755], Real: 4
# Prediccion: [ 0.20044608  0.14994015  0.05675787 -0.02061086 -0.01358027 -0.05114068], Real: 0
# Prediccion: [ 0.1390429  -0.3447102   0.07949028 -0.2321347  -0.21149661 -0.13199611], Real: 4
# Prediccion: [ 0.20330569  0.11320802 -0.05059351  0.02833976  0.1263734  -0.31919654], Real: 0
# Prediccion: [ 0.01503079  0.07924491 -0.00576137  0.05846996 -0.00202912 -0.06822192], Real: 1
# Prediccion: [-0.04325739  0.03637437  0.24183821  0.04852198 -0.10105148  0.33410277], Real: 4
# Prediccion: [ 0.00887404 -0.0489215   0.09462829 -0.24487672 -0.07352853 -0.26822801], Real: 2
# Prediccion: [ 0.09122175 -0.17882107  0.15164846 -0.29079255 -0.10543847 -0.18943338], Real: 1
# Prediccion: [ 0.00177787 -0.12110323  0.16581865 -0.1467577  -0.02114101 -0.09301814], Real: 3
# Prediccion: [ 0.10209545 -0.05434154  0.17876558 -0.24122327 -0.07262615 -0.08848127], Real: 5

# %%
print('Precisión de entrenamiento: {:.2f} %'.format(np.mean(pred == y_test) * 100))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[108], line 1
# ----> 1 print('Precisión de entrenamiento: {:.2f} %'.format(np.mean(pred == y_test) * 100))
#
# ValueError: operands could not be broadcast together with shapes (3200,6) (3200,)
